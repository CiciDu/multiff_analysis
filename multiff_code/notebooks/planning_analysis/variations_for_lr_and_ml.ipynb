# %% [markdown]
# # Import packages

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import os, sys
for p in [Path.cwd()] + list(Path.cwd().parents):
    if p.name == 'Multifirefly-Project':
        os.chdir(p)
        sys.path.insert(0, str(p / 'multiff_analysis/multiff_code/methods'))
        break



from pattern_discovery import monkey_landing_in_ff
from machine_learning.ml_methods import regression_utils, classification_utils, prep_ml_data_utils
from visualization.matplotlib_tools import plot_trials
from planning_analysis.show_planning import examine_null_arcs
from planning_analysis.show_planning.cur_vs_nxt_ff import cvn_from_ref_class
from planning_analysis.only_cur_ff import only_cur_ff_x_sess_class
from planning_analysis.plan_factors import plan_factors_utils, build_factor_comp, plan_factors_class, monkey_plan_factors_x_sess_class
from planning_analysis.agent_analysis import compare_monkey_and_agent_utils, agent_plan_factors_x_sess_class, cmp_monkey_agent_plan_class
from machine_learning.ml_methods import ml_methods_class, prep_ml_data_utils
from planning_analysis.plan_factors import monkey_plan_factors_x_sess_class, monkey_plan_factors_x_sess_class
from planning_analysis.variations_of_factors_vs_results import make_variations_utils, plot_variations_utils, process_variations_utils

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import rc
import os, sys, sys

plt.rcParams["animation.html"] = "html5"
os.environ['KMP_DUPLICATE_LIB_OK']='True'
rc('animation', html='jshtml')
matplotlib.rcParams.update(matplotlib.rcParamsDefault)
matplotlib.rcParams['animation.embed_limit'] = 2**128
pd.set_option('display.float_format', lambda x: '%.5f' % x)
np.set_printoptions(suppress=True)
pd.options.display.max_rows = 101
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_item = None
raw_data_folder_path = "all_monkey_data/raw_monkey_data/monkey_Bruno/data_0328"

# %% [markdown]
# # Run overnight

# %%
exists_ok = True
#list_of_curv_traj_window_before_stop = [[-50, 0]]
list_of_curv_traj_window_before_stop = [[-25, 0], [-50, 0], [-75, -0],
                                        [-25, 0], [-50, 0], [-75, -0],
                                        ]

for monkey_name in ['monkey_Schro', 'monkey_Bruno']:
    for opt_arc_type in ['norm_opt_arc', 'opt_arc_stop_closest', 'opt_arc_stop_first_vis_bdry']:
        # suppress printed output
        # with open(os.devnull, "w") as f, contextlib.redirect_stdout(f):

        ps = monkey_plan_factors_x_sess_class.PlanAcrossSessions(monkey_name=monkey_name, 
                                                                opt_arc_type=opt_arc_type)
        overall_median_info = ps.make_or_retrieve_overall_median_info(exists_ok=exists_ok,
                                                                    list_of_curv_traj_window_before_stop=list_of_curv_traj_window_before_stop,
                                                                    )
        all_perc_info = ps.make_or_retrieve_all_perc_info(exists_ok=exists_ok)
        
        # all_cur_and_nxt_lr_pred_ff_df = ps.make_or_retrieve_all_cur_and_nxt_lr_pred_ff_df(exists_ok=exists_ok)
        # all_cur_and_nxt_lr_df = ps.make_or_retrieve_all_cur_and_nxt_lr_df(exists_ok=exists_ok)
        # all_cur_and_nxt_clf_df = ps.make_or_retrieve_all_cur_and_nxt_clf_df()

        # # # can comment out the below if not needed
        # osfxs = only_cur_ff_x_sess_class.OnlyStopFFAcrossSessions(monkey_name=monkey_name)
        # all_only_cur_lr_df = osfxs.make_or_retrieve_all_only_cur_lr_df(exists_ok=exists_ok)
        # all_only_cur_ml_df = osfxs.make_or_retrieve_all_only_cur_ml_df(exists_ok=exists_ok)
# Out:
# Successfully retrieved overall_median_info from  all_monkey_data/planning/monkey_Schro/combined_data/cur_and_nxt/data_comparison/norm_opt_arc/overall_median_info.csv
# Saved overall_median_info_path to all_monkey_data/planning/monkey_Schro/combined_data/cur_and_nxt/data_comparison/norm_opt_arc/overall_median_info.csv
# Columns (among selected ones for examination) that have variations:
# ===================================================
#
# test_or_control ['test' 'control']
# ===================================================
#
# ref_point_value [  -0.2   -0.1    0.     0.1    0.2 -100.  -150. ]
# ===================================================
#
# if_test_nxt_ff_group_appear_after_stop ['ff_must_seen_after_stop' 'ff_no_seen_after_stop' 'flexible']
# ===================================================
#
# curv_traj_window_before_stop ['[-25, 0]' '[-50, 0]' '[-75, 0]']
# Columns (among selected ones for examination) that have variations:
# ===================================================
#
# test_or_control ['test' 'control']
# ===================================================
#
# if_test_nxt_ff_group_appear_after_stop ['ff_must_seen_after_stop' 'ff_no_seen_after_stop' 'flexible']
# Successfully retrieved overall_median_info from  all_monkey_data/planning/monkey_Schro/combined_data/cur_and_nxt/data_comparison/opt_arc_stop_closest/overall_median_info.csv
# Saved overall_median_info_path to all_monkey_data/planning/monkey_Schro/combined_data/cur_and_nxt/data_comparison/opt_arc_stop_closest/overall_median_info.csv
# Columns (among selected ones for examination) that have variations:
# ===================================================
#
# test_or_control ['test' 'control']
# ===================================================
#
# ref_point_value [  -0.2   -0.1    0.     0.1    0.2 -100.  -150. ]
# ===================================================
#
# if_test_nxt_ff_group_appear_after_stop ['ff_must_seen_after_stop' 'ff_no_seen_after_stop' 'flexible']
# ===================================================
#
# curv_traj_window_before_stop ['[-25, 0]' '[-50, 0]' '[-75, 0]']
# Columns (among selected ones for examination) that have variations:
# ===================================================
#
# test_or_control ['test' 'control']
# ===================================================
#
# if_test_nxt_ff_group_appear_after_stop ['ff_must_seen_after_stop' 'ff_no_seen_after_stop' 'flexible']
# Successfully retrieved overall_median_info from  all_monkey_data/planning/monkey_Schro/combined_data/cur_and_nxt/data_comparison/opt_arc_stop_first_vis_bdry/overall_median_info.csv
# Saved overall_median_info_path to all_monkey_data/planning/monkey_Schro/combined_data/cur_and_nxt/data_comparison/opt_arc_stop_first_vis_bdry/overall_median_info.csv
# Columns (among selected ones for examination) that have variations:
# ===================================================
#
# test_or_control ['test' 'control']
# ===================================================
#
# ref_point_value [  -0.2   -0.1    0.     0.1    0.2 -100.  -150. ]
# ===================================================
#
# if_test_nxt_ff_group_appear_after_stop ['ff_must_seen_after_stop' 'ff_no_seen_after_stop' 'flexible']
# ===================================================
#
# curv_traj_window_before_stop ['[-25, 0]' '[-50, 0]' '[-75, 0]']
# Columns (among selected ones for examination) that have variations:
# ===================================================
#
# test_or_control ['test' 'control']
# ===================================================
#
# if_test_nxt_ff_group_appear_after_stop ['ff_must_seen_after_stop' 'ff_no_seen_after_stop' 'flexible']
# Successfully retrieved overall_median_info from  all_monkey_data/planning/monkey_Bruno/combined_data/cur_and_nxt/data_comparison/norm_opt_arc/overall_median_info.csv
# Saved overall_median_info_path to all_monkey_data/planning/monkey_Bruno/combined_data/cur_and_nxt/data_comparison/norm_opt_arc/overall_median_info.csv
# Columns (among selected ones for examination) that have variations:
# ===================================================
#
# test_or_control ['test' 'control']
# ===================================================
#
# ref_point_value [  -0.2   -0.1    0.     0.1    0.2 -100.  -150. ]
# ===================================================
#
# if_test_nxt_ff_group_appear_after_stop ['ff_must_seen_after_stop' 'ff_no_seen_after_stop' 'flexible']
# ===================================================
#
# curv_traj_window_before_stop ['[-25, 0]' '[-50, 0]' '[-75, 0]']
# Columns (among selected ones for examination) that have variations:
# ===================================================
#
# test_or_control ['test' 'control']
# ===================================================
#
# if_test_nxt_ff_group_appear_after_stop ['ff_must_seen_after_stop' 'ff_no_seen_after_stop' 'flexible']
# Successfully retrieved overall_median_info from  all_monkey_data/planning/monkey_Bruno/combined_data/cur_and_nxt/data_comparison/opt_arc_stop_closest/overall_median_info.csv
# Saved overall_median_info_path to all_monkey_data/planning/monkey_Bruno/combined_data/cur_and_nxt/data_comparison/opt_arc_stop_closest/overall_median_info.csv
# Columns (among selected ones for examination) that have variations:
# ===================================================
#
# test_or_control ['test' 'control']
# ===================================================
#
# ref_point_value [  -0.2   -0.1    0.     0.1    0.2 -100.  -150. ]
# ===================================================
#
# if_test_nxt_ff_group_appear_after_stop ['ff_must_seen_after_stop' 'ff_no_seen_after_stop' 'flexible']
# ===================================================
#
# curv_traj_window_before_stop ['[-25, 0]' '[-50, 0]' '[-75, 0]']
# Columns (among selected ones for examination) that have variations:
# ===================================================
#
# test_or_control ['test' 'control']
# ===================================================
#
# if_test_nxt_ff_group_appear_after_stop ['ff_must_seen_after_stop' 'ff_no_seen_after_stop' 'flexible']
# Successfully retrieved overall_median_info from  all_monkey_data/planning/monkey_Bruno/combined_data/cur_and_nxt/data_comparison/opt_arc_stop_first_vis_bdry/overall_median_info.csv
# Saved overall_median_info_path to all_monkey_data/planning/monkey_Bruno/combined_data/cur_and_nxt/data_comparison/opt_arc_stop_first_vis_bdry/overall_median_info.csv
# Columns (among selected ones for examination) that have variations:
# ===================================================
#
# test_or_control ['test' 'control']
# ===================================================
#
# ref_point_value [  -0.2   -0.1    0.     0.1    0.2 -100.  -150. ]
# ===================================================
#
# if_test_nxt_ff_group_appear_after_stop ['ff_must_seen_after_stop' 'ff_no_seen_after_stop' 'flexible']
# ===================================================
#
# curv_traj_window_before_stop ['[-25, 0]' '[-50, 0]' '[-75, 0]']
# Columns (among selected ones for examination) that have variations:
# ===================================================
#
# test_or_control ['test' 'control']
# ===================================================
#
# if_test_nxt_ff_group_appear_after_stop ['ff_must_seen_after_stop' 'ff_no_seen_after_stop' 'flexible']

# %%
stop!
# Out:
#   Cell In[12], line 1
#     stop!
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # debug

# %%
pfas = agent_plan_factors_x_sess_class.PlanFactorsAcrossAgentSessions(num_steps_per_dataset=100000)
agent_overall_median_info = pfas.make_or_retrieve_overall_median_info()
# Out:
# ref_point_mode     time after cur ff visible
# ref_point_value                     -0.20000
# monkey_name                             None
# stored                                 False
# Name: 0, dtype: object
# Will make new combd_heading_df_x_sessions for the agent because [Errno combd_heading_df_x_sessions (cur_vis_-0_2) is not in the folder: ] RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/combined_data/cur_and_nxt/data/combd_heading_info/opt_arc_stop_closest/control/.
#
# model_folder_name: RL_models/SB3_stored_models/all_agents/env1_relu/ff3/dv10_dw10_w10_mem3
# data_name: data_0
#
# Getting test heading info control heading info ......
# Retrieving cur_vis_-0_2_window_-50cm_0cm from RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/diff_in_curv_df/opt_arc_stop_closest/test/cur_vis_-0_2_window_-50cm_0cm succeeded
# Data missing. Will get agent data first. Error message:  [Errno 2] No such file or directory: 'RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/heading_info_df/opt_arc_stop_closest/test/cur_vis_-0_2'
# model_folder_name: RL_models/SB3_stored_models/all_agents/env1_relu/ff3/dv10_dw10_w10_mem3
# Failed to retrieve monkey data. Will make new monkey data. Error:  cannot access local variable 'monkey_information' where it is not associated with a value
# Made agent with the following params: {'learning_rate': 0.0003, 'batch_size': 1024, 'target_update_interval': 50, 'buffer_size': 1000000, 'learning_starts': 10000, 'train_freq': TrainFreq(frequency=100, unit=<TrainFrequencyUnit.STEP: 'step'>), 'gradient_steps': 10, 'ent_coef': 'auto', 'policy_kwargs': {'activation_fn': <class 'torch.nn.modules.activation.ReLU'>, 'net_arch': [256, 128], 'use_sde': False}, 'gamma': 0.998}
# Loaded existing agent: RL_models/SB3_stored_models/all_agents/env1_relu/ff3/dv10_dw10_w10_mem3/best_model.zip
# Params from agent after loading:
# {'learning_rate': 0.0003, 'batch_size': 1024, 'target_update_interval': 50, 'buffer_size': 1000000, 'learning_starts': 10000, 'train_freq': TrainFreq(frequency=100, unit=<TrainFrequencyUnit.STEP: 'step'>), 'gradient_steps': 10, 'ent_coef': 'auto', 'policy_kwargs': {'activation_fn': <class 'torch.nn.modules.activation.ReLU'>, 'net_arch': [256, 128], 'use_sde': False}, 'gamma': 0.998}
# /opt/miniconda3/envs/ff_venv2/lib/python3.11/site-packages/stable_baselines3/common/save_util.py:167: UserWarning:
#
# Could not deserialize object lr_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: code() argument 13 must be str, not int
# Failed to retrieve monkey data. Will make new monkey data. Error:  cannot access local variable 'monkey_information' where it is not associated with a value
# Collecting new agent data......
# Removed all files in the folder: RL_models/SB3_stored_models/all_collected_data/processed_data/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0
# TIME before resetting: 0
# current linear_terminal_vel:  0.01
# current angular_terminal_vel:  0.01
# current dt:  0.1
# current full_memory:  30
# current dv_cost_factor:  10
# current dw_cost_factor:  10
# current w_cost_factor:  10
# current distance2center_cost:  0
# current flash_on_interval:  0.3
# current num_obs_ff:  3
# current max_in_memory_time:  3
# Step:  1000 out of 100000
# Step:  2000 out of 100000
# Step:  3000 out of 100000
# Step:  4000 out of 100000
# Step:  5000 out of 100000
# Step:  6000 out of 100000
# Step:  7000 out of 100000
# Step:  8000 out of 100000
# Step:  9000 out of 100000
# Step:  10000 out of 100000
# Step:  11000 out of 100000
# Step:  12000 out of 100000
# Step:  13000 out of 100000
# Step:  14000 out of 100000
# Step:  15000 out of 100000
# Step:  16000 out of 100000
# Step:  17000 out of 100000
# Step:  18000 out of 100000
# Step:  19000 out of 100000
# Step:  20000 out of 100000
# Step:  21000 out of 100000
# Step:  22000 out of 100000
# Step:  23000 out of 100000
# Step:  24000 out of 100000
# Step:  25000 out of 100000
# Step:  26000 out of 100000
# Step:  27000 out of 100000
# Step:  28000 out of 100000
# Step:  29000 out of 100000
# Step:  30000 out of 100000
# Step:  31000 out of 100000
# Step:  32000 out of 100000
# Step:  33000 out of 100000
# Step:  34000 out of 100000
# Step:  35000 out of 100000
# Step:  36000 out of 100000
# Step:  37000 out of 100000
# Step:  38000 out of 100000
# Step:  39000 out of 100000
# Step:  40000 out of 100000
# Step:  41000 out of 100000
# Step:  42000 out of 100000
# Step:  43000 out of 100000
# Step:  44000 out of 100000
# Step:  45000 out of 100000
# Step:  46000 out of 100000
# Step:  47000 out of 100000
# Step:  48000 out of 100000
# Step:  49000 out of 100000
# Step:  50000 out of 100000
# Step:  51000 out of 100000
# Step:  52000 out of 100000
# Step:  53000 out of 100000
# Step:  54000 out of 100000
# Step:  55000 out of 100000
# Step:  56000 out of 100000
# Step:  57000 out of 100000
# Step:  58000 out of 100000
# Step:  59000 out of 100000
# Step:  60000 out of 100000
# Step:  61000 out of 100000
# Step:  62000 out of 100000
# Step:  63000 out of 100000
# Step:  64000 out of 100000
# Step:  65000 out of 100000
# Step:  66000 out of 100000
# Step:  67000 out of 100000
# Step:  68000 out of 100000
# Step:  69000 out of 100000
# Step:  70000 out of 100000
# Step:  71000 out of 100000
# Step:  72000 out of 100000
# Step:  73000 out of 100000
# Step:  74000 out of 100000
# Step:  75000 out of 100000
# Step:  76000 out of 100000
# Step:  77000 out of 100000
# Step:  78000 out of 100000
# Step:  79000 out of 100000
# Step:  80000 out of 100000
# Step:  81000 out of 100000
# Step:  82000 out of 100000
# Step:  83000 out of 100000
# Step:  84000 out of 100000
# Step:  85000 out of 100000
# Step:  86000 out of 100000
# Step:  87000 out of 100000
# Step:  88000 out of 100000
# Step:  89000 out of 100000
# Step:  90000 out of 100000
# Step:  91000 out of 100000
# Step:  92000 out of 100000
# Step:  93000 out of 100000
# Step:  94000 out of 100000
# Step:  95000 out of 100000
# Step:  96000 out of 100000
# Step:  97000 out of 100000
# Step:  98000 out of 100000
# Step:  99000 out of 100000
# Firefly capture rate:  1.0224999999980728
# saved monkey_information and ff info at RL_models/SB3_stored_models/all_collected_data/processed_data/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0
# Warnings: currently, only ff in obs at each step are used in ff_dataframe. All ff are labeled 'visible' regardless of their actual time since last visible.
# made ff_dataframe
# saved ff_dataframe at RL_models/SB3_stored_models/all_collected_data/processed_data/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/ff_dataframe.csv
# Removed 0 rows out of 3370 rows where cur_ff was not visible bbas or nxt_ff was not visible both bbas and bsans
# shared_stops_near_ff_df has 3370 rows
# Retrieving shared_stops_near_ff_df succeeded
# [Note] When calling modify_position_of_ff_with_big_angle_for_finding_null_arc, Even with `remove_i_o_modify_rows_with_big_ff_angles=False`, some rows may still be removed (e.g., negative ff_y_relative). Use this function mainly for curvature calculation.
# [Warning] 49.937% of ff_y_relative values are negative and will be removed.
# [Warning] 42.035% of ff_x_relative > ff_y_relative. Will be modified instead.
# [Note] When calling modify_position_of_ff_with_big_angle_for_finding_null_arc, Even with `remove_i_o_modify_rows_with_big_ff_angles=False`, some rows may still be removed (e.g., negative ff_y_relative). Use this function mainly for curvature calculation.
# [Warning] 5.843% of ff_y_relative values are negative and will be removed.
# [Warning] 39.748% of ff_x_relative > ff_y_relative. Will be modified instead.
# Warning: 59 arc out of 1112 arcs where ff is to the left of the monkey has an angle larger than 90 degrees. The max is 90.00000728703485. We will adjust them by making them a little less than 90.
# Warning: 35 arc out of 1112 arcs where ff is to the left of the monkey has an angle larger than 90 degrees. The max is 90.00000354876987. We will adjust them by making them a little less than 90.
# Warning: 2 arc out of 1112 arcs where ff is to the left of the monkey has an angle larger than 90 degrees. The max is 90.00000059872389. We will adjust them by making them a little less than 90.
# Number of new ff xy within 1 cm of monkey: 3 out of 1112. Setting them to monkey position.
# Note: when calculating angles to ff centers, 3 rows are too close to the monkey/agent: less than 0.001 m. Their angles are set to 0.
# Retrieving cur_vis_-0_2_window_-50cm_0cm from RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/diff_in_curv_df/opt_arc_stop_closest/test/cur_vis_-0_2_window_-50cm_0cm succeeded
# Failed to retrieve heading_info_df because of [Errno 2] No such file or directory: 'RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/heading_info_df/opt_arc_stop_closest/test/cur_vis_-0_2'; will make new heading_info_df
# Stored new heading_info_df (agent_cur_vis_0_2) (1112 rows) in RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/heading_info_df/opt_arc_stop_closest/test/agent_cur_vis_0_2
# Retrieving cur_vis_-0_2_window_-50cm_0cm from RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/diff_in_curv_df/opt_arc_stop_closest/test/cur_vis_-0_2_window_-50cm_0cm succeeded
# [Note] When calling modify_position_of_ff_with_big_angle_for_finding_null_arc, Even with `remove_i_o_modify_rows_with_big_ff_angles=False`, some rows may still be removed (e.g., negative ff_y_relative). Use this function mainly for curvature calculation.
# [Warning] 49.073% of ff_y_relative values are negative and will be removed.
# [Warning] 43.689% of ff_x_relative > ff_y_relative. Will be modified instead.
# [Note] When calling modify_position_of_ff_with_big_angle_for_finding_null_arc, Even with `remove_i_o_modify_rows_with_big_ff_angles=False`, some rows may still be removed (e.g., negative ff_y_relative). Use this function mainly for curvature calculation.
# [Warning] 5.651% of ff_y_relative values are negative and will be removed.
# [Warning] 41.146% of ff_x_relative > ff_y_relative. Will be modified instead.
# Warning: 23 arc out of 384 arcs where ff is to the left of the monkey has an angle larger than 90 degrees. The max is 90.00000139135193. We will adjust them by making them a little less than 90.
# Warning: 22 arc out of 384 arcs where ff is to the left of the monkey has an angle larger than 90 degrees. The max is 90.00000281749915. We will adjust them by making them a little less than 90.
# Number of new ff xy within 1 cm of monkey: 1 out of 384. Setting them to monkey position.
# Note: when calculating angles to ff centers, 1 rows are too close to the monkey/agent: less than 0.001 m. Their angles are set to 0.
# Retrieving cur_vis_-0_2_window_-50cm_0cm from RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/diff_in_curv_df/opt_arc_stop_closest/control/cur_vis_-0_2_window_-50cm_0cm succeeded
# Failed to retrieve heading_info_df because of [Errno 2] No such file or directory: 'RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/heading_info_df/opt_arc_stop_closest/control/cur_vis_-0_2'; will make new heading_info_df
# Stored new heading_info_df (agent_cur_vis_0_2) (384 rows) in RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/heading_info_df/opt_arc_stop_closest/control/agent_cur_vis_0_2
# Retrieving cur_vis_-0_2_window_-50cm_0cm from RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/diff_in_curv_df/opt_arc_stop_closest/control/cur_vis_-0_2_window_-50cm_0cm succeeded
# Stored new combd_heading_df_x_sessions for test data in RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/combined_data/cur_and_nxt/data/combd_heading_info/opt_arc_stop_closest/test/agent_cur_vis_0_2
# Stored new combd_heading_df_x_sessions for control data in RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/combined_data/cur_and_nxt/data/combd_heading_info/opt_arc_stop_closest/control/agent_cur_vis_0_2
# Stored new all_median_info in  RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/combined_data/cur_and_nxt/data_comparison/opt_arc_stop_closest/all_median_info
# ref_point_mode     time after cur ff visible
# ref_point_value                     -0.10000
# monkey_name                             None
# stored                                 False
# Name: 1, dtype: object
# Will make new combd_heading_df_x_sessions for the agent because [Errno combd_heading_df_x_sessions (cur_vis_-0_1) is not in the folder: ] RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/combined_data/cur_and_nxt/data/combd_heading_info/opt_arc_stop_closest/control/.
#
# model_folder_name: RL_models/SB3_stored_models/all_agents/env1_relu/ff3/dv10_dw10_w10_mem3
# data_name: data_0
#
# Getting test heading info control heading info ......
# Retrieving cur_vis_-0_1_window_-50cm_0cm from RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/diff_in_curv_df/opt_arc_stop_closest/test/cur_vis_-0_1_window_-50cm_0cm succeeded
# Data missing. Will get agent data first. Error message:  [Errno 2] No such file or directory: 'RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/heading_info_df/opt_arc_stop_closest/test/cur_vis_-0_1'
# model_folder_name: RL_models/SB3_stored_models/all_agents/env1_relu/ff3/dv10_dw10_w10_mem3
# Failed to retrieve monkey data. Will make new monkey data. Error:  cannot access local variable 'monkey_information' where it is not associated with a value
# Made agent with the following params: {'learning_rate': 0.0003, 'batch_size': 1024, 'target_update_interval': 50, 'buffer_size': 1000000, 'learning_starts': 10000, 'train_freq': TrainFreq(frequency=100, unit=<TrainFrequencyUnit.STEP: 'step'>), 'gradient_steps': 10, 'ent_coef': 'auto', 'policy_kwargs': {'activation_fn': <class 'torch.nn.modules.activation.ReLU'>, 'net_arch': [256, 128], 'use_sde': False}, 'gamma': 0.998}
# Loaded existing agent: RL_models/SB3_stored_models/all_agents/env1_relu/ff3/dv10_dw10_w10_mem3/best_model.zip
# Params from agent after loading:
# {'learning_rate': 0.0003, 'batch_size': 1024, 'target_update_interval': 50, 'buffer_size': 1000000, 'learning_starts': 10000, 'train_freq': TrainFreq(frequency=100, unit=<TrainFrequencyUnit.STEP: 'step'>), 'gradient_steps': 10, 'ent_coef': 'auto', 'policy_kwargs': {'activation_fn': <class 'torch.nn.modules.activation.ReLU'>, 'net_arch': [256, 128], 'use_sde': False}, 'gamma': 0.998}
# /opt/miniconda3/envs/ff_venv2/lib/python3.11/site-packages/stable_baselines3/common/save_util.py:167: UserWarning:
#
# Could not deserialize object lr_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: code() argument 13 must be str, not int
# Failed to retrieve monkey data. Will make new monkey data. Error:  cannot access local variable 'monkey_information' where it is not associated with a value
# Collecting new agent data......
# Removed all files in the folder: RL_models/SB3_stored_models/all_collected_data/processed_data/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0
# TIME before resetting: 0
# current linear_terminal_vel:  0.01
# current angular_terminal_vel:  0.01
# current dt:  0.1
# current full_memory:  30
# current dv_cost_factor:  10
# current dw_cost_factor:  10
# current w_cost_factor:  10
# current distance2center_cost:  0
# current flash_on_interval:  0.3
# current num_obs_ff:  3
# current max_in_memory_time:  3
# Step:  1000 out of 100000
# Step:  2000 out of 100000
# Step:  3000 out of 100000
# Step:  4000 out of 100000
# Step:  5000 out of 100000
# Step:  6000 out of 100000
# Step:  7000 out of 100000
# Step:  8000 out of 100000
# Step:  9000 out of 100000
# Step:  10000 out of 100000
# Step:  11000 out of 100000
# Step:  12000 out of 100000
# Step:  13000 out of 100000
# Step:  14000 out of 100000
# Step:  15000 out of 100000
# Step:  16000 out of 100000
# Step:  17000 out of 100000
# Step:  18000 out of 100000
# Step:  19000 out of 100000
# Step:  20000 out of 100000
# Step:  21000 out of 100000
# Step:  22000 out of 100000
# Step:  23000 out of 100000
# Step:  24000 out of 100000
# Step:  25000 out of 100000
# Step:  26000 out of 100000
# Step:  27000 out of 100000
# Step:  28000 out of 100000
# Step:  29000 out of 100000
# Step:  30000 out of 100000
# Step:  31000 out of 100000
# Step:  32000 out of 100000
# Step:  33000 out of 100000
# Step:  34000 out of 100000
# Step:  35000 out of 100000
# Step:  36000 out of 100000
# Step:  37000 out of 100000
# Step:  38000 out of 100000
# Step:  39000 out of 100000
# Step:  40000 out of 100000
# Step:  41000 out of 100000
# Step:  42000 out of 100000
# Step:  43000 out of 100000
# Step:  44000 out of 100000
# Step:  45000 out of 100000
# Step:  46000 out of 100000
# Step:  47000 out of 100000
# Step:  48000 out of 100000
# Step:  49000 out of 100000
# Step:  50000 out of 100000
# Step:  51000 out of 100000
# Step:  52000 out of 100000
# Step:  53000 out of 100000
# Step:  54000 out of 100000
# Step:  55000 out of 100000
# Step:  56000 out of 100000
# Step:  57000 out of 100000
# Step:  58000 out of 100000
# Step:  59000 out of 100000
# Step:  60000 out of 100000
# Step:  61000 out of 100000
# Step:  62000 out of 100000
# Step:  63000 out of 100000
# Step:  64000 out of 100000
# Step:  65000 out of 100000
# Step:  66000 out of 100000
# Step:  67000 out of 100000
# Step:  68000 out of 100000
# Step:  69000 out of 100000
# Step:  70000 out of 100000
# Step:  71000 out of 100000
# Step:  72000 out of 100000
# Step:  73000 out of 100000
# Step:  74000 out of 100000
# Step:  75000 out of 100000
# Step:  76000 out of 100000
# Step:  77000 out of 100000
# Step:  78000 out of 100000
# Step:  79000 out of 100000
# Step:  80000 out of 100000
# Step:  81000 out of 100000
# Step:  82000 out of 100000
# Step:  83000 out of 100000
# Step:  84000 out of 100000
# Step:  85000 out of 100000
# Step:  86000 out of 100000
# Step:  87000 out of 100000
# Step:  88000 out of 100000
# Step:  89000 out of 100000
# Step:  90000 out of 100000
# Step:  91000 out of 100000
# Step:  92000 out of 100000
# Step:  93000 out of 100000
# Step:  94000 out of 100000
# Step:  95000 out of 100000
# Step:  96000 out of 100000
# Step:  97000 out of 100000
# Step:  98000 out of 100000
# Step:  99000 out of 100000
# Firefly capture rate:  1.0261999999980658
# saved monkey_information and ff info at RL_models/SB3_stored_models/all_collected_data/processed_data/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0
# Warnings: currently, only ff in obs at each step are used in ff_dataframe. All ff are labeled 'visible' regardless of their actual time since last visible.
# made ff_dataframe
# saved ff_dataframe at RL_models/SB3_stored_models/all_collected_data/processed_data/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/ff_dataframe.csv
# Removed 0 rows out of 3370 rows where cur_ff was not visible bbas or nxt_ff was not visible both bbas and bsans
# shared_stops_near_ff_df has 3370 rows
# Retrieving shared_stops_near_ff_df succeeded
# [Note] When calling modify_position_of_ff_with_big_angle_for_finding_null_arc, Even with `remove_i_o_modify_rows_with_big_ff_angles=False`, some rows may still be removed (e.g., negative ff_y_relative). Use this function mainly for curvature calculation.
# [Warning] 48.316% of ff_y_relative values are negative and will be removed.
# [Warning] 41.352% of ff_x_relative > ff_y_relative. Will be modified instead.
# [Note] When calling modify_position_of_ff_with_big_angle_for_finding_null_arc, Even with `remove_i_o_modify_rows_with_big_ff_angles=False`, some rows may still be removed (e.g., negative ff_y_relative). Use this function mainly for curvature calculation.
# [Warning] 5.931% of ff_y_relative values are negative and will be removed.
# [Warning] 38.704% of ff_x_relative > ff_y_relative. Will be modified instead.
# Warning: 47 arc out of 1142 arcs where ff is to the left of the monkey has an angle larger than 90 degrees. The max is 90.0000021504587. We will adjust them by making them a little less than 90.
# Warning: 29 arc out of 1142 arcs where ff is to the left of the monkey has an angle larger than 90 degrees. The max is 90.00000211842139. We will adjust them by making them a little less than 90.
# Warning: 1 arc out of 1142 arcs where ff is to the left of the monkey has an angle larger than 90 degrees. The max is 90.00000056260092. We will adjust them by making them a little less than 90.
# Number of new ff xy within 1 cm of monkey: 6 out of 1142. Setting them to monkey position.
# Note: when calculating angles to ff centers, 6 rows are too close to the monkey/agent: less than 0.001 m. Their angles are set to 0.
# Retrieving cur_vis_-0_1_window_-50cm_0cm from RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/diff_in_curv_df/opt_arc_stop_closest/test/cur_vis_-0_1_window_-50cm_0cm succeeded
# Failed to retrieve heading_info_df because of [Errno 2] No such file or directory: 'RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/heading_info_df/opt_arc_stop_closest/test/cur_vis_-0_1'; will make new heading_info_df
# Stored new heading_info_df (agent_cur_vis_0_1) (1142 rows) in RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/heading_info_df/opt_arc_stop_closest/test/agent_cur_vis_0_1
# Retrieving cur_vis_-0_1_window_-50cm_0cm from RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/diff_in_curv_df/opt_arc_stop_closest/test/cur_vis_-0_1_window_-50cm_0cm succeeded
# [Note] When calling modify_position_of_ff_with_big_angle_for_finding_null_arc, Even with `remove_i_o_modify_rows_with_big_ff_angles=False`, some rows may still be removed (e.g., negative ff_y_relative). Use this function mainly for curvature calculation.
# [Warning] 48.814% of ff_y_relative values are negative and will be removed.
# [Warning] 42.927% of ff_x_relative > ff_y_relative. Will be modified instead.
# [Note] When calling modify_position_of_ff_with_big_angle_for_finding_null_arc, Even with `remove_i_o_modify_rows_with_big_ff_angles=False`, some rows may still be removed (e.g., negative ff_y_relative). Use this function mainly for curvature calculation.
# [Warning] 7.353% of ff_y_relative values are negative and will be removed.
# [Warning] 37.831% of ff_x_relative > ff_y_relative. Will be modified instead.
# Warning: 16 arc out of 378 arcs where ff is to the left of the monkey has an angle larger than 90 degrees. The max is 90.00000318680114. We will adjust them by making them a little less than 90.
# Warning: 11 arc out of 378 arcs where ff is to the left of the monkey has an angle larger than 90 degrees. The max is 90.0000052928433. We will adjust them by making them a little less than 90.
# Warning: 1 arc out of 378 arcs where ff is to the left of the monkey has an angle larger than 90 degrees. The max is 90.0000014245419. We will adjust them by making them a little less than 90.
# Number of new ff xy within 1 cm of monkey: 2 out of 378. Setting them to monkey position.
# Note: when calculating angles to ff centers, 2 rows are too close to the monkey/agent: less than 0.001 m. Their angles are set to 0.
# Retrieving cur_vis_-0_1_window_-50cm_0cm from RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/diff_in_curv_df/opt_arc_stop_closest/control/cur_vis_-0_1_window_-50cm_0cm succeeded
# Failed to retrieve heading_info_df because of [Errno 2] No such file or directory: 'RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/heading_info_df/opt_arc_stop_closest/control/cur_vis_-0_1'; will make new heading_info_df
# Stored new heading_info_df (agent_cur_vis_0_1) (378 rows) in RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/heading_info_df/opt_arc_stop_closest/control/agent_cur_vis_0_1
# Retrieving cur_vis_-0_1_window_-50cm_0cm from RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/diff_in_curv_df/opt_arc_stop_closest/control/cur_vis_-0_1_window_-50cm_0cm succeeded
# Stored new combd_heading_df_x_sessions for test data in RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/combined_data/cur_and_nxt/data/combd_heading_info/opt_arc_stop_closest/test/agent_cur_vis_0_1
# Stored new combd_heading_df_x_sessions for control data in RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/combined_data/cur_and_nxt/data/combd_heading_info/opt_arc_stop_closest/control/agent_cur_vis_0_1
# /opt/miniconda3/envs/ff_venv2/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /opt/miniconda3/envs/ff_venv2/lib/python3.11/site-packages/numpy/core/_methods.py:121: RuntimeWarning:
#
# invalid value encountered in divide
# Stored new all_median_info in  RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/combined_data/cur_and_nxt/data_comparison/opt_arc_stop_closest/all_median_info
# ref_point_mode     time after cur ff visible
# ref_point_value                      0.00000
# monkey_name                             None
# stored                                 False
# Name: 2, dtype: object
# Will make new combd_heading_df_x_sessions for the agent because [Errno combd_heading_df_x_sessions (cur_vis_0_0) is not in the folder: ] RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/combined_data/cur_and_nxt/data/combd_heading_info/opt_arc_stop_closest/control/.
#
# model_folder_name: RL_models/SB3_stored_models/all_agents/env1_relu/ff3/dv10_dw10_w10_mem3
# data_name: data_0
#
# Getting test heading info control heading info ......
# Retrieving cur_vis_0_0_window_-50cm_0cm from RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/diff_in_curv_df/opt_arc_stop_closest/test/cur_vis_0_0_window_-50cm_0cm succeeded
# Data missing. Will get agent data first. Error message:  [Errno 2] No such file or directory: 'RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/heading_info_df/opt_arc_stop_closest/test/cur_vis_0_0'
# model_folder_name: RL_models/SB3_stored_models/all_agents/env1_relu/ff3/dv10_dw10_w10_mem3
# Failed to retrieve monkey data. Will make new monkey data. Error:  cannot access local variable 'monkey_information' where it is not associated with a value
# Made agent with the following params: {'learning_rate': 0.0003, 'batch_size': 1024, 'target_update_interval': 50, 'buffer_size': 1000000, 'learning_starts': 10000, 'train_freq': TrainFreq(frequency=100, unit=<TrainFrequencyUnit.STEP: 'step'>), 'gradient_steps': 10, 'ent_coef': 'auto', 'policy_kwargs': {'activation_fn': <class 'torch.nn.modules.activation.ReLU'>, 'net_arch': [256, 128], 'use_sde': False}, 'gamma': 0.998}
# Loaded existing agent: RL_models/SB3_stored_models/all_agents/env1_relu/ff3/dv10_dw10_w10_mem3/best_model.zip
# Params from agent after loading:
# {'learning_rate': 0.0003, 'batch_size': 1024, 'target_update_interval': 50, 'buffer_size': 1000000, 'learning_starts': 10000, 'train_freq': TrainFreq(frequency=100, unit=<TrainFrequencyUnit.STEP: 'step'>), 'gradient_steps': 10, 'ent_coef': 'auto', 'policy_kwargs': {'activation_fn': <class 'torch.nn.modules.activation.ReLU'>, 'net_arch': [256, 128], 'use_sde': False}, 'gamma': 0.998}
# /opt/miniconda3/envs/ff_venv2/lib/python3.11/site-packages/stable_baselines3/common/save_util.py:167: UserWarning:
#
# Could not deserialize object lr_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: code() argument 13 must be str, not int
# Failed to retrieve monkey data. Will make new monkey data. Error:  cannot access local variable 'monkey_information' where it is not associated with a value
# Collecting new agent data......
# Removed all files in the folder: RL_models/SB3_stored_models/all_collected_data/processed_data/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0
# TIME before resetting: 0
# current linear_terminal_vel:  0.01
# current angular_terminal_vel:  0.01
# current dt:  0.1
# current full_memory:  30
# current dv_cost_factor:  10
# current dw_cost_factor:  10
# current w_cost_factor:  10
# current distance2center_cost:  0
# current flash_on_interval:  0.3
# current num_obs_ff:  3
# current max_in_memory_time:  3
# Step:  1000 out of 100000
# Step:  2000 out of 100000
# Step:  3000 out of 100000
# Step:  4000 out of 100000
# Step:  5000 out of 100000
# Step:  6000 out of 100000
# Step:  7000 out of 100000
# Step:  8000 out of 100000
# Step:  9000 out of 100000
# Step:  10000 out of 100000
# Step:  11000 out of 100000
# Step:  12000 out of 100000
# Step:  13000 out of 100000
# Step:  14000 out of 100000
# Step:  15000 out of 100000
# Step:  16000 out of 100000
# Step:  17000 out of 100000
# Step:  18000 out of 100000
# Step:  19000 out of 100000
# Step:  20000 out of 100000
# Step:  21000 out of 100000
# Step:  22000 out of 100000
# Step:  23000 out of 100000
# Step:  24000 out of 100000
# Step:  25000 out of 100000
# Step:  26000 out of 100000
# Step:  27000 out of 100000
# Step:  28000 out of 100000
# Step:  29000 out of 100000
# Step:  30000 out of 100000
# Step:  31000 out of 100000
# Step:  32000 out of 100000
# Step:  33000 out of 100000
# Step:  34000 out of 100000
# Step:  35000 out of 100000
# Step:  36000 out of 100000
# Step:  37000 out of 100000
# Step:  38000 out of 100000
# Step:  39000 out of 100000
# Step:  40000 out of 100000
# Step:  41000 out of 100000
# Step:  42000 out of 100000
# Step:  43000 out of 100000
# Step:  44000 out of 100000
# Step:  45000 out of 100000
# Step:  46000 out of 100000
# Step:  47000 out of 100000
# Step:  48000 out of 100000
# Step:  49000 out of 100000
# Step:  50000 out of 100000
# Step:  51000 out of 100000
# Step:  52000 out of 100000
# Step:  53000 out of 100000
# Step:  54000 out of 100000
# Step:  55000 out of 100000
# Step:  56000 out of 100000
# Step:  57000 out of 100000
# Step:  58000 out of 100000
# Step:  59000 out of 100000
# Step:  60000 out of 100000
# Step:  61000 out of 100000
# Step:  62000 out of 100000
# Step:  63000 out of 100000
# Step:  64000 out of 100000
# Step:  65000 out of 100000
# Step:  66000 out of 100000
# Step:  67000 out of 100000
# Step:  68000 out of 100000
# Step:  69000 out of 100000
# Step:  70000 out of 100000
# Step:  71000 out of 100000
# Step:  72000 out of 100000
# Step:  73000 out of 100000
# Step:  74000 out of 100000
# Step:  75000 out of 100000
# Step:  76000 out of 100000
# Step:  77000 out of 100000
# Step:  78000 out of 100000
# Step:  79000 out of 100000
# Step:  80000 out of 100000
# Step:  81000 out of 100000
# Step:  82000 out of 100000
# Step:  83000 out of 100000
# Step:  84000 out of 100000
# Step:  85000 out of 100000
# Step:  86000 out of 100000
# Step:  87000 out of 100000
# Step:  88000 out of 100000
# Step:  89000 out of 100000
# Step:  90000 out of 100000
# Step:  91000 out of 100000
# Step:  92000 out of 100000
# Step:  93000 out of 100000
# Step:  94000 out of 100000
# Step:  95000 out of 100000
# Step:  96000 out of 100000
# Step:  97000 out of 100000
# Step:  98000 out of 100000
# Step:  99000 out of 100000
# Firefly capture rate:  1.0389999999980417
# saved monkey_information and ff info at RL_models/SB3_stored_models/all_collected_data/processed_data/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0
# Warnings: currently, only ff in obs at each step are used in ff_dataframe. All ff are labeled 'visible' regardless of their actual time since last visible.
# made ff_dataframe
# saved ff_dataframe at RL_models/SB3_stored_models/all_collected_data/processed_data/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/ff_dataframe.csv
# Removed 0 rows out of 3370 rows where cur_ff was not visible bbas or nxt_ff was not visible both bbas and bsans
# shared_stops_near_ff_df has 3370 rows
# Retrieving shared_stops_near_ff_df succeeded
# [Note] When calling modify_position_of_ff_with_big_angle_for_finding_null_arc, Even with `remove_i_o_modify_rows_with_big_ff_angles=False`, some rows may still be removed (e.g., negative ff_y_relative). Use this function mainly for curvature calculation.
# [Warning] 51.902% of ff_y_relative values are negative and will be removed.
# [Warning] 53.998% of ff_x_relative > ff_y_relative. Will be modified instead.
# [Note] When calling modify_position_of_ff_with_big_angle_for_finding_null_arc, Even with `remove_i_o_modify_rows_with_big_ff_angles=False`, some rows may still be removed (e.g., negative ff_y_relative). Use this function mainly for curvature calculation.
# [Warning] 7.917% of ff_y_relative values are negative and will be removed.
# [Warning] 51.121% of ff_x_relative > ff_y_relative. Will be modified instead.
# Warning: 50 arc out of 1070 arcs where ff is to the left of the monkey has an angle larger than 90 degrees. The max is 90.00000422380745. We will adjust them by making them a little less than 90.
# Warning: 46 arc out of 1070 arcs where ff is to the left of the monkey has an angle larger than 90 degrees. The max is 90.00000192857217. We will adjust them by making them a little less than 90.
# Warning: 1 arc out of 1070 arcs where ff is to the left of the monkey has an angle larger than 90 degrees. The max is 90.00000148739637. We will adjust them by making them a little less than 90.
# Number of new ff xy within 1 cm of monkey: 5 out of 1070. Setting them to monkey position.
# Note: when calculating angles to ff centers, 5 rows are too close to the monkey/agent: less than 0.001 m. Their angles are set to 0.
# Retrieving cur_vis_0_0_window_-50cm_0cm from RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/diff_in_curv_df/opt_arc_stop_closest/test/cur_vis_0_0_window_-50cm_0cm succeeded
# Failed to retrieve heading_info_df because of [Errno 2] No such file or directory: 'RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/heading_info_df/opt_arc_stop_closest/test/cur_vis_0_0'; will make new heading_info_df
# Stored new heading_info_df (agent_cur_vis_0_0) (1070 rows) in RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/heading_info_df/opt_arc_stop_closest/test/agent_cur_vis_0_0
# Retrieving cur_vis_0_0_window_-50cm_0cm from RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/diff_in_curv_df/opt_arc_stop_closest/test/cur_vis_0_0_window_-50cm_0cm succeeded
# [Note] When calling modify_position_of_ff_with_big_angle_for_finding_null_arc, Even with `remove_i_o_modify_rows_with_big_ff_angles=False`, some rows may still be removed (e.g., negative ff_y_relative). Use this function mainly for curvature calculation.
# [Warning] 52.696% of ff_y_relative values are negative and will be removed.
# [Warning] 51.295% of ff_x_relative > ff_y_relative. Will be modified instead.
# [Note] When calling modify_position_of_ff_with_big_angle_for_finding_null_arc, Even with `remove_i_o_modify_rows_with_big_ff_angles=False`, some rows may still be removed (e.g., negative ff_y_relative). Use this function mainly for curvature calculation.
# [Warning] 6.736% of ff_y_relative values are negative and will be removed.
# [Warning] 51.389% of ff_x_relative > ff_y_relative. Will be modified instead.
# Warning: 22 arc out of 360 arcs where ff is to the left of the monkey has an angle larger than 90 degrees. The max is 90.0000021868368. We will adjust them by making them a little less than 90.
# Warning: 20 arc out of 360 arcs where ff is to the left of the monkey has an angle larger than 90 degrees. The max is 90.00000253381316. We will adjust them by making them a little less than 90.
# Warning: 1 arc out of 360 arcs where ff is to the left of the monkey has an angle larger than 90 degrees. The max is 90.00000120773687. We will adjust them by making them a little less than 90.
# Number of new ff xy within 1 cm of monkey: 1 out of 360. Setting them to monkey position.
# Note: when calculating angles to ff centers, 1 rows are too close to the monkey/agent: less than 0.001 m. Their angles are set to 0.
# Retrieving cur_vis_0_0_window_-50cm_0cm from RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/diff_in_curv_df/opt_arc_stop_closest/control/cur_vis_0_0_window_-50cm_0cm succeeded
# Failed to retrieve heading_info_df because of [Errno 2] No such file or directory: 'RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/heading_info_df/opt_arc_stop_closest/control/cur_vis_0_0'; will make new heading_info_df
# Stored new heading_info_df (agent_cur_vis_0_0) (360 rows) in RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/heading_info_df/opt_arc_stop_closest/control/agent_cur_vis_0_0
# Retrieving cur_vis_0_0_window_-50cm_0cm from RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/diff_in_curv_df/opt_arc_stop_closest/control/cur_vis_0_0_window_-50cm_0cm succeeded
# Stored new combd_heading_df_x_sessions for test data in RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/combined_data/cur_and_nxt/data/combd_heading_info/opt_arc_stop_closest/test/agent_cur_vis_0_0
# Stored new combd_heading_df_x_sessions for control data in RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/combined_data/cur_and_nxt/data/combd_heading_info/opt_arc_stop_closest/control/agent_cur_vis_0_0
# Stored new all_median_info in  RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/combined_data/cur_and_nxt/data_comparison/opt_arc_stop_closest/all_median_info
# ref_point_mode     time after cur ff visible
# ref_point_value                      0.10000
# monkey_name                             None
# stored                                 False
# Name: 3, dtype: object
# Will make new combd_heading_df_x_sessions for the agent because [Errno combd_heading_df_x_sessions (cur_vis_0_1) is not in the folder: ] RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/combined_data/cur_and_nxt/data/combd_heading_info/opt_arc_stop_closest/control/.
#
# model_folder_name: RL_models/SB3_stored_models/all_agents/env1_relu/ff3/dv10_dw10_w10_mem3
# data_name: data_0
#
# Getting test heading info control heading info ......
# Retrieving cur_vis_0_1_window_-50cm_0cm from RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/diff_in_curv_df/opt_arc_stop_closest/test/cur_vis_0_1_window_-50cm_0cm succeeded
# Data missing. Will get agent data first. Error message:  [Errno 2] No such file or directory: 'RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/heading_info_df/opt_arc_stop_closest/test/cur_vis_0_1'
# model_folder_name: RL_models/SB3_stored_models/all_agents/env1_relu/ff3/dv10_dw10_w10_mem3
# Failed to retrieve monkey data. Will make new monkey data. Error:  cannot access local variable 'monkey_information' where it is not associated with a value
# Made agent with the following params: {'learning_rate': 0.0003, 'batch_size': 1024, 'target_update_interval': 50, 'buffer_size': 1000000, 'learning_starts': 10000, 'train_freq': TrainFreq(frequency=100, unit=<TrainFrequencyUnit.STEP: 'step'>), 'gradient_steps': 10, 'ent_coef': 'auto', 'policy_kwargs': {'activation_fn': <class 'torch.nn.modules.activation.ReLU'>, 'net_arch': [256, 128], 'use_sde': False}, 'gamma': 0.998}
# Loaded existing agent: RL_models/SB3_stored_models/all_agents/env1_relu/ff3/dv10_dw10_w10_mem3/best_model.zip
# Params from agent after loading:
# {'learning_rate': 0.0003, 'batch_size': 1024, 'target_update_interval': 50, 'buffer_size': 1000000, 'learning_starts': 10000, 'train_freq': TrainFreq(frequency=100, unit=<TrainFrequencyUnit.STEP: 'step'>), 'gradient_steps': 10, 'ent_coef': 'auto', 'policy_kwargs': {'activation_fn': <class 'torch.nn.modules.activation.ReLU'>, 'net_arch': [256, 128], 'use_sde': False}, 'gamma': 0.998}
# /opt/miniconda3/envs/ff_venv2/lib/python3.11/site-packages/stable_baselines3/common/save_util.py:167: UserWarning:
#
# Could not deserialize object lr_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: code() argument 13 must be str, not int
# Failed to retrieve monkey data. Will make new monkey data. Error:  cannot access local variable 'monkey_information' where it is not associated with a value
# Collecting new agent data......
# Removed all files in the folder: RL_models/SB3_stored_models/all_collected_data/processed_data/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0
# TIME before resetting: 0
# current linear_terminal_vel:  0.01
# current angular_terminal_vel:  0.01
# current dt:  0.1
# current full_memory:  30
# current dv_cost_factor:  10
# current dw_cost_factor:  10
# current w_cost_factor:  10
# current distance2center_cost:  0
# current flash_on_interval:  0.3
# current num_obs_ff:  3
# current max_in_memory_time:  3
# Step:  1000 out of 100000
# Step:  2000 out of 100000
# Step:  3000 out of 100000
# Step:  4000 out of 100000
# Step:  5000 out of 100000
# Step:  6000 out of 100000
# Step:  7000 out of 100000
# Step:  8000 out of 100000
# Step:  9000 out of 100000
# Step:  10000 out of 100000
# Step:  11000 out of 100000
# Step:  12000 out of 100000
# Step:  13000 out of 100000
# Step:  14000 out of 100000
# Step:  15000 out of 100000
# Step:  16000 out of 100000
# Step:  17000 out of 100000
# Step:  18000 out of 100000
# Step:  19000 out of 100000
# Step:  20000 out of 100000
# Step:  21000 out of 100000
# Step:  22000 out of 100000
# Step:  23000 out of 100000
# Step:  24000 out of 100000
# Step:  25000 out of 100000
# Step:  26000 out of 100000
# Step:  27000 out of 100000
# Step:  28000 out of 100000
# Step:  29000 out of 100000
# Step:  30000 out of 100000
# Step:  31000 out of 100000
# Step:  32000 out of 100000
# Step:  33000 out of 100000
# Step:  34000 out of 100000
# Step:  35000 out of 100000
# Step:  36000 out of 100000
# Step:  37000 out of 100000
# Step:  38000 out of 100000
# Step:  39000 out of 100000
# Step:  40000 out of 100000
# Step:  41000 out of 100000
# Step:  42000 out of 100000
# Step:  43000 out of 100000
# Step:  44000 out of 100000
# Step:  45000 out of 100000
# Step:  46000 out of 100000
# Step:  47000 out of 100000
# Step:  48000 out of 100000
# Step:  49000 out of 100000
# Step:  50000 out of 100000
# Step:  51000 out of 100000
# Step:  52000 out of 100000
# Step:  53000 out of 100000
# Step:  54000 out of 100000
# Step:  55000 out of 100000
# Step:  56000 out of 100000
# Step:  57000 out of 100000
# Step:  58000 out of 100000
# Step:  59000 out of 100000
# Step:  60000 out of 100000
# Step:  61000 out of 100000
# Step:  62000 out of 100000
# Step:  63000 out of 100000
# Step:  64000 out of 100000
# Step:  65000 out of 100000
# Step:  66000 out of 100000
# Step:  67000 out of 100000
# Step:  68000 out of 100000
# Step:  69000 out of 100000
# Step:  70000 out of 100000
# Step:  71000 out of 100000
# Step:  72000 out of 100000
# Step:  73000 out of 100000
# Step:  74000 out of 100000
# Step:  75000 out of 100000
# Step:  76000 out of 100000
# Step:  77000 out of 100000
# Step:  78000 out of 100000
# Step:  79000 out of 100000
# Step:  80000 out of 100000
# Step:  81000 out of 100000
# Step:  82000 out of 100000
# Step:  83000 out of 100000
# Step:  84000 out of 100000
# Step:  85000 out of 100000
# Step:  86000 out of 100000
# Step:  87000 out of 100000
# Step:  88000 out of 100000
# Step:  89000 out of 100000
# Step:  90000 out of 100000
# Step:  91000 out of 100000
# Step:  92000 out of 100000
# Step:  93000 out of 100000
# Step:  94000 out of 100000
# Step:  95000 out of 100000
# Step:  96000 out of 100000
# Step:  97000 out of 100000
# Step:  98000 out of 100000
# Step:  99000 out of 100000
# Firefly capture rate:  1.0337999999980514
# saved monkey_information and ff info at RL_models/SB3_stored_models/all_collected_data/processed_data/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0
# Warnings: currently, only ff in obs at each step are used in ff_dataframe. All ff are labeled 'visible' regardless of their actual time since last visible.
# made ff_dataframe
# saved ff_dataframe at RL_models/SB3_stored_models/all_collected_data/processed_data/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/ff_dataframe.csv
# Removed 0 rows out of 3370 rows where cur_ff was not visible bbas or nxt_ff was not visible both bbas and bsans
# shared_stops_near_ff_df has 3370 rows
# Retrieving shared_stops_near_ff_df succeeded
# [Note] When calling modify_position_of_ff_with_big_angle_for_finding_null_arc, Even with `remove_i_o_modify_rows_with_big_ff_angles=False`, some rows may still be removed (e.g., negative ff_y_relative). Use this function mainly for curvature calculation.
# [Warning] 52.401% of ff_y_relative values are negative and will be removed.
# [Warning] 52.870% of ff_x_relative > ff_y_relative. Will be modified instead.
# [Note] When calling modify_position_of_ff_with_big_angle_for_finding_null_arc, Even with `remove_i_o_modify_rows_with_big_ff_angles=False`, some rows may still be removed (e.g., negative ff_y_relative). Use this function mainly for curvature calculation.
# [Warning] 7.934% of ff_y_relative values are negative and will be removed.
# [Warning] 51.326% of ff_x_relative > ff_y_relative. Will be modified instead.
# Warning: 41 arc out of 1056 arcs where ff is to the left of the monkey has an angle larger than 90 degrees. The max is 90.00000476460848. We will adjust them by making them a little less than 90.
# Warning: 27 arc out of 1056 arcs where ff is to the left of the monkey has an angle larger than 90 degrees. The max is 90.00000567647342. We will adjust them by making them a little less than 90.
# Warning: 1 arc out of 1056 arcs where ff is to the left of the monkey has an angle larger than 90 degrees. The max is 90.00000042072297. We will adjust them by making them a little less than 90.
# Number of new ff xy within 1 cm of monkey: 7 out of 1056. Setting them to monkey position.
# Note: when calculating angles to ff centers, 7 rows are too close to the monkey/agent: less than 0.001 m. Their angles are set to 0.
# Retrieving cur_vis_0_1_window_-50cm_0cm from RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/diff_in_curv_df/opt_arc_stop_closest/test/cur_vis_0_1_window_-50cm_0cm succeeded
# Failed to retrieve heading_info_df because of [Errno 2] No such file or directory: 'RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/heading_info_df/opt_arc_stop_closest/test/cur_vis_0_1'; will make new heading_info_df
# Stored new heading_info_df (agent_cur_vis_0_1) (1056 rows) in RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/heading_info_df/opt_arc_stop_closest/test/agent_cur_vis_0_1
# Retrieving cur_vis_0_1_window_-50cm_0cm from RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/individual_data_sessions/data_0/diff_in_curv_df/opt_arc_stop_closest/test/cur_vis_0_1_window_-50cm_0cm succeeded
# ...
#      52 self.overall_median_info = pd.DataFrame([])
#      53 for curv_traj_window_before_stop in list_of_curv_traj_window_before_stop:
# ---> 54     temp_overall_median_info = make_variations_utils.make_variations_df_across_ref_point_values(self.make_all_median_info,
#      55                                                                                                 ref_point_params_based_on_mode=ref_point_params_based_on_mode,
#      56                                                                                                 monkey_name=self.monkey_name,
#      57                                                                                                 variation_func_kwargs={'all_median_info_exists_ok': all_median_info_exists_ok,
#      58                                                                                                                        'curv_traj_window_before_stop': curv_traj_window_before_stop,
#      59                                                                                                                        'save_data': save_data,
#      60                                                                                                                        'combd_heading_df_x_sessions_exists_ok': combd_heading_df_x_sessions_exists_ok,
#      61                                                                                                                        'stops_near_ff_df_exists_ok': stops_near_ff_df_exists_ok,
#      62                                                                                                                        'heading_info_df_exists_ok': heading_info_df_exists_ok,
#      63                                                                                                                        },
#      64                                                                                                 path_to_save=None,
#      65                                                                                                 )
#      66     temp_overall_median_info['curv_traj_window_before_stop'] = str(
#      67         curv_traj_window_before_stop)
#      68     self.overall_median_info = pd.concat(
#      69         [self.overall_median_info, temp_overall_median_info], axis=0)
#
# File ~/Documents/Multifirefly-Project/multiff_analysis/multiff_code/methods/planning_analysis/variations_of_factors_vs_results/make_variations_utils.py:378, in make_variations_df_across_ref_point_values(variation_func, variation_func_kwargs, ref_point_params_based_on_mode, monkey_name, path_to_save)
#     376 for index, row in variations_list.iterrows():
#     377     print(row)
# --> 378     df = variation_func(ref_point_mode=row['ref_point_mode'],
#     379                         ref_point_value=row['ref_point_value'],
#     380                         **variation_func_kwargs)
#     381     all_variations_df = pd.concat([all_variations_df, df], axis=0)
#     382     all_variations_df.reset_index(drop=True, inplace=True)
#
# File ~/Documents/Multifirefly-Project/multiff_analysis/multiff_code/methods/planning_analysis/variations_of_factors_vs_results/_compare_y_values_class.py:123, in _CompareYValues.make_all_median_info(self, ref_point_mode, ref_point_value, curv_traj_window_before_stop, all_median_info_exists_ok, combd_heading_df_x_sessions_exists_ok, stops_near_ff_df_exists_ok, heading_info_df_exists_ok, verbose, save_data)
#     121     print('Successfully retrieved all_median_info from ', df_path)
#     122 else:
# --> 123     self.get_test_and_ctrl_heading_info_df_across_sessions(ref_point_mode=ref_point_mode, ref_point_value=ref_point_value,
#     124                                                            curv_traj_window_before_stop=curv_traj_window_before_stop,
#     125                                                            heading_info_df_exists_ok=heading_info_df_exists_ok,
#     126                                                            stops_near_ff_df_exists_ok=stops_near_ff_df_exists_ok, save_data=save_data,
#     127                                                            combd_heading_df_x_sessions_exists_ok=combd_heading_df_x_sessions_exists_ok)
#     128     self.all_median_info = make_variations_utils.make_all_median_info_from_test_and_ctrl_heading_info_df(self.test_heading_info_df,
#     129                                                                                                          self.ctrl_heading_info_df, verbose=verbose)
#     130     self.all_median_info['ref_point_mode'] = ref_point_mode
#
# File ~/Documents/Multifirefly-Project/multiff_analysis/multiff_code/methods/planning_analysis/agent_analysis/agent_plan_factors_x_sess_class.py:271, in PlanFactorsAcrossAgentSessions.get_test_and_ctrl_heading_info_df_across_sessions(self, num_datasets_to_collect, ref_point_mode, ref_point_value, curv_traj_window_before_stop, heading_info_df_exists_ok, combd_heading_df_x_sessions_exists_ok, stops_near_ff_df_exists_ok, curv_of_traj_mode, window_for_curv_of_traj, use_curv_to_ff_center, save_data, **env_kwargs)
#     268 except Exception as e:
#     269     print(
#     270         f'Will make new combd_heading_df_x_sessions for the agent because {e}.')
# --> 271     self.make_combd_heading_df_x_sessions(num_steps_per_dataset=self.num_steps_per_dataset, num_datasets_to_collect=num_datasets_to_collect,
#     272                                           ref_point_mode=ref_point_mode, ref_point_value=ref_point_value,
#     273                                           curv_traj_window_before_stop=curv_traj_window_before_stop,
#     274                                           heading_info_df_exists_ok=heading_info_df_exists_ok,
#     275                                           stops_near_ff_df_exists_ok=stops_near_ff_df_exists_ok,
#     276                                           curv_of_traj_mode=curv_of_traj_mode, window_for_curv_of_traj=window_for_curv_of_traj,
#     277                                           use_curv_to_ff_center=use_curv_to_ff_center,
#     278                                           save_data=save_data,
#     279                                           **env_kwargs)
#
# File ~/Documents/Multifirefly-Project/multiff_analysis/multiff_code/methods/planning_analysis/agent_analysis/agent_plan_factors_x_sess_class.py:218, in PlanFactorsAcrossAgentSessions.make_combd_heading_df_x_sessions(self, num_datasets_to_collect, ref_point_mode, ref_point_value, curv_traj_window_before_stop, heading_info_df_exists_ok, stops_near_ff_df_exists_ok, curv_of_traj_mode, window_for_curv_of_traj, use_curv_to_ff_center, save_data, **env_kwargs)
#     216     print(' ')
#     217     print('Getting test heading info control heading info ......')
# --> 218     self.pfa.get_test_and_ctrl_heading_info_df_for_one_session(ref_point_mode=ref_point_mode,
#     219                                                                ref_point_value=ref_point_value,
#     220                                                                curv_traj_window_before_stop=curv_traj_window_before_stop,
#     221                                                                heading_info_df_exists_ok=heading_info_df_exists_ok,
#     222                                                                stops_near_ff_df_exists_ok=stops_near_ff_df_exists_ok,
#     223                                                                curv_of_traj_mode=curv_of_traj_mode,
#     224                                                                window_for_curv_of_traj=window_for_curv_of_traj,
#     225                                                                use_curv_to_ff_center=use_curv_to_ff_center,
#     226                                                                save_data=save_data,
#     227                                                                n_steps=self.num_steps_per_dataset,
#     228                                                                **env_kwargs)
#     230     self._add_heading_info_to_combd_heading_info(data_name)
#     232 self.test_heading_info_df.reset_index(drop=True, inplace=True)
#
# File ~/Documents/Multifirefly-Project/multiff_analysis/multiff_code/methods/planning_analysis/agent_analysis/agent_plan_factors_class.py:146, in PlanFactorsOfAgent.get_test_and_ctrl_heading_info_df_for_one_session(self, ref_point_mode, ref_point_value, curv_traj_window_before_stop, monkey_data_exists_ok, heading_info_df_exists_ok, stops_near_ff_df_exists_ok, use_curv_to_ff_center, save_data, curv_of_traj_mode, window_for_curv_of_traj, n_steps, merge_diff_in_curv_df_to_heading_info, **env_kwargs)
#     144 except Exception as e:
#     145     print('Data missing. Will get agent data first. Error message: ', e)
# --> 146     self.get_agent_data(
#     147         n_steps=n_steps, exists_ok=monkey_data_exists_ok, save_data=save_data, **env_kwargs)
#     148     self._load_agent_data_onto_pf()
#     149     for test_or_control in ['test', 'control']:
#
# File ~/Documents/Multifirefly-Project/multiff_analysis/multiff_code/methods/planning_analysis/agent_analysis/agent_plan_factors_class.py:32, in PlanFactorsOfAgent.get_agent_data(self, n_steps, exists_ok, save_data, **env_kwargs)
#      26 env_kwargs['episode_len'] = episode_len
#      28 self.rl_ff = sb3_for_multiff_class.SB3forMultifirefly(model_folder_name=self.model_folder_name,
#      29                                                       data_name=self.data_name,
#      30                                                       overall_folder='',
#      31                                                       **env_kwargs)
# ---> 32 self.rl_ff.streamline_getting_data_from_agent(
#      33     n_steps=n_steps, exists_ok=exists_ok, save_data=save_data)
#
# File ~/Documents/Multifirefly-Project/multiff_analysis/multiff_code/methods/machine_learning/RL/SB3/rl_for_multiff_class.py:336, in _RLforMultifirefly.streamline_getting_data_from_agent(self, n_steps, exists_ok, save_data, load_replay_buffer, **env_kwargs)
#     334 self.make_agent()
#     335 self.load_agent(load_replay_buffer=load_replay_buffer)
# --> 336 self.collect_data(
#     337     n_steps=n_steps, exists_ok=exists_ok, save_data=save_data)
#
# File ~/Documents/Multifirefly-Project/multiff_analysis/multiff_code/methods/machine_learning/RL/SB3/rl_for_multiff_class.py:185, in _RLforMultifirefly.collect_data(self, n_steps, exists_ok, save_data)
#     182     except Exception as e:
#     183         print(
#     184             "Failed to retrieve monkey data. Will make new monkey data. Error: ", e)
# --> 185         self.run_agent_to_collect_data(
#     186             n_steps=n_steps, save_data=save_data)
#     187 else:
#     188     self.run_agent_to_collect_data(
#     189         n_steps=n_steps, save_data=save_data)
#
# File ~/Documents/Multifirefly-Project/multiff_analysis/multiff_code/methods/machine_learning/RL/SB3/rl_for_multiff_class.py:210, in _RLforMultifirefly.run_agent_to_collect_data(self, n_steps, save_data)
#     207 else:
#     208     raise ValueError("sb3_or_lstm should be either 'sb3' or 'lstm'")
# --> 210 self._run_agent_to_collect_data(
#     211     n_steps=n_steps, save_data=save_data, LSTM=LSTM)
#
# File ~/Documents/Multifirefly-Project/multiff_analysis/multiff_code/methods/machine_learning/RL/SB3/rl_for_multiff_class.py:232, in _RLforMultifirefly._run_agent_to_collect_data(self, exists_ok, n_steps, save_data, LSTM)
#     224             print('Removed all files in the folder:',
#     225                   self.processed_data_folder_path)
#     227 self.n_steps = n_steps
#     229 self.monkey_information, self.ff_flash_sorted, self.ff_caught_T_sorted, self.ff_believed_position_sorted, \
#     230     self.ff_real_position_sorted, self.ff_life_sorted, self.ff_flash_end_sorted, self.caught_ff_num, self.total_ff_num, \
#     231     self.obs_ff_indices_in_ff_dataframe, self.sorted_indices_all, self.ff_in_obs_df \
# --> 232     = collect_agent_data_utils.collect_agent_data_func(self.env_for_data_collection, self.sac_model, n_steps=self.n_steps, LSTM=LSTM)
#     233 self.ff_index_sorted = np.arange(len(self.ff_life_sorted))
#     234 self.eval_ff_capture_rate = len(
#     235     self.ff_flash_end_sorted)/self.monkey_information['time'].max()
#
# File ~/Documents/Multifirefly-Project/multiff_analysis/multiff_code/methods/machine_learning/RL/env_related/collect_agent_data_utils.py:125, in collect_agent_data_func(env, sac_model, n_steps, LSTM, hidden_dim, deterministic, first_obs)
#     123 else:
#     124     action, _ = sac_model.predict(obs, deterministic=True)
# --> 125     obs, reward, done, _, info = env.step(action)
#     126     # memory_ff_indices_all.append(env.ff_in_memory_indices)
#     128 monkey_x.append(env.agentx.item())
#
# File ~/Documents/Multifirefly-Project/multiff_analysis/multiff_code/methods/machine_learning/RL/env_related/base_env.py:255, in MultiFF.step(self, action)
#     253 self.state_step(action)
#     254 # update the observation
# --> 255 self.obs = self.beliefs().numpy()
#     256 # get reward
#     257 reward = self.calculate_reward()
#
# File ~/Documents/Multifirefly-Project/multiff_analysis/multiff_code/methods/machine_learning/RL/env_related/base_env.py:329, in MultiFF.beliefs(self)
#     325 self._check_for_num_targets()
#     327 self._further_process_after_check_for_num_targets()
# --> 329 self._get_ff_array_for_belief()
#     331 obs = torch.flatten(self.ff_array.transpose(0, 1))
#     333 # append action to the observation
#
# File ~/Documents/Multifirefly-Project/multiff_analysis/multiff_code/methods/machine_learning/RL/env_related/env_for_sb3.py:69, in CollectInformation._get_ff_array_for_belief(self)
#      68 def _get_ff_array_for_belief(self):
# ---> 69     return EnvForSB3._get_ff_array_for_belief(self)
#
# File ~/Documents/Multifirefly-Project/multiff_analysis/multiff_code/methods/machine_learning/RL/env_related/env_for_sb3.py:26, in EnvForSB3._get_ff_array_for_belief(self)
#      25 def _get_ff_array_for_belief(self):
# ---> 26     self._get_ff_array_for_belief_common(
#      27         self.ff_in_memory_indices, add_memory=True, add_ff_time_since_start_visible=False)
#
# File ~/Documents/Multifirefly-Project/multiff_analysis/multiff_code/methods/machine_learning/RL/env_related/base_env.py:457, in MultiFF._get_ff_array_for_belief_common(self, ff_indices, add_memory, add_ff_time_since_start_visible)
#     454 else:
#     455     self.topk_indices = env_utils._get_sorted_indices(
#     456         ff_indices, self.ff_distance_all)
# --> 457     self.ff_array = self._get_ff_array_given_indices(
#     458         add_memory=add_memory, add_ff_time_since_start_visible=add_ff_time_since_start_visible)
#     459     num_needed_ff = self.num_obs_ff - torch.numel(ff_indices)
#     460     placeholder_ff = env_utils._get_placeholder_ff(
#     461         add_memory, add_ff_time_since_start_visible, self.invisible_distance)
#
# File ~/Documents/Multifirefly-Project/multiff_analysis/multiff_code/methods/machine_learning/RL/env_related/base_env.py:432, in MultiFF._get_ff_array_given_indices(self, add_memory, add_ff_time_since_start_visible)
#     428 self.angle_to_center_topk_noisy, angle_to_boundary_topk_noisy = env_utils.calculate_angles_to_ff_in_pytorch(self.ffxy_topk_noisy, self.agentx, self.agenty, self.agentheading,
#     429                                                                                                             self.ff_radius, ffdistance=self.distance_topk_noisy)
#     430 if add_memory:
#     431     # Concatenate angles, distance, and memory
# --> 432     self.ff_array = torch.stack((self.angle_to_center_topk_noisy, angle_to_boundary_topk_noisy, self.distance_topk_noisy,
#     433                                  self.ff_memory_all[self.topk_indices]), dim=0)
#     434 elif add_ff_time_since_start_visible:
#     435     self.ff_array = torch.stack((self.angle_to_center_topk_noisy, angle_to_boundary_topk_noisy, self.distance_topk_noisy,
#     436                                  self.ff_time_since_start_visible[self.topk_indices]), dim=0)
#
# KeyboardInterrupt:

# %% [markdown]
# # Y values

# %% [markdown]
# ## overall_median_info

# %% [markdown]
# ### monkey

# %% [markdown]
# #### combine monkey and arc type

# %%
ps = monkey_plan_factors_x_sess_class.PlanAcrossSessions()
# combine both monkeys
monkey_median_df = ps.combine_overall_median_info_across_monkeys_and_opt_arc_types()
# Out:
# Columns (among selected ones for examination) that have variations:
# ===================================================
#
# test_or_control ['test' 'control']
# ===================================================
#
# ref_point_value [  -0.2   -0.1    0.     0.1    0.2 -100.  -150. ]
# ===================================================
#
# if_test_nxt_ff_group_appear_after_stop ['ff_must_seen_after_stop' 'ff_no_seen_after_stop' 'flexible']
# ===================================================
#
# monkey_name ['monkey_Schro' 'monkey_Bruno']
# ===================================================
#
# opt_arc_type ['norm_opt_arc' 'opt_arc_stop_closest' 'opt_arc_stop_first_vis_bdry']
# ===================================================
#
# curv_traj_window_before_stop ['[-25, 0]' '[-50, 0]' '[-75, 0]']

# %% [markdown]
# #### for individual monkey, and one arc type

# %%
ps = monkey_plan_factors_x_sess_class.PlanAcrossSessions(monkey_name='monkey_Schro')
monkey_median_df = ps.make_or_retrieve_overall_median_info(exists_ok=True, 
                                                                all_median_info_exists_ok=True)
# Out:
# Successfully retrieved overall_median_info from  all_monkey_data/planning/monkey_Schro/combined_data/cur_and_nxt/data_comparison/opt_arc_stop_closest/overall_median_info.csv
# Saved overall_median_info_path to all_monkey_data/planning/monkey_Schro/combined_data/cur_and_nxt/data_comparison/opt_arc_stop_closest/overall_median_info.csv
# Columns (among selected ones for examination) that have variations:
# ===================================================
#
# test_or_control ['test' 'control']
# ===================================================
#
# ref_point_value [  -0.2   -0.1    0.     0.1    0.2 -100.  -150. ]
# ===================================================
#
# if_test_nxt_ff_group_appear_after_stop ['ff_must_seen_after_stop' 'ff_no_seen_after_stop' 'flexible']
# ===================================================
#
# curv_traj_window_before_stop ['[-25, 0]' '[-50, 0]' '[-75, 0]']

# %%
ps = monkey_plan_factors_x_sess_class.PlanAcrossSessions(monkey_name='monkey_Bruno')
monkey_median_df = ps.make_or_retrieve_overall_median_info(exists_ok=True, 
                                                                    all_median_info_exists_ok=True)
# Out:
# Successfully retrieved overall_median_info from  all_monkey_data/planning/monkey_Bruno/combined_data/cur_and_nxt/data_comparison/opt_arc_stop_closest/overall_median_info.csv
# Saved overall_median_info_path to all_monkey_data/planning/monkey_Bruno/combined_data/cur_and_nxt/data_comparison/opt_arc_stop_closest/overall_median_info.csv
# Columns (among selected ones for examination) that have variations:
# ===================================================
#
# test_or_control ['test' 'control']
# ===================================================
#
# ref_point_value [  -0.2   -0.1    0.     0.1    0.2 -100.  -150. ]
# ===================================================
#
# if_test_nxt_ff_group_appear_after_stop ['ff_must_seen_after_stop' 'ff_no_seen_after_stop' 'flexible']
# ===================================================
#
# curv_traj_window_before_stop ['[-25, 0]' '[-50, 0]' '[-75, 0]']

# %% [markdown]
# ### agent

# %%
pfas = agent_plan_factors_x_sess_class.PlanFactorsAcrossAgentSessions(num_steps_per_dataset=100000)
agent_overall_median_info = pfas.make_or_retrieve_overall_median_info()
# Out:
# Successfully retrieved overall_median_info from  RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/combined_data/cur_and_nxt/data_comparison/opt_arc_stop_closest/overall_median_info.csv
# Saved overall_median_info_path to RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/combined_data/cur_and_nxt/data_comparison/opt_arc_stop_closest/overall_median_info.csv
# Columns (among selected ones for examination) that have variations:
# ===================================================
#
# test_or_control ['test' 'control']
# ===================================================
#
# ref_point_value [  -0.2   -0.1    0.     0.1    0.2 -100.  -150. ]
# ===================================================
#
# if_test_nxt_ff_group_appear_after_stop ['ff_must_seen_after_stop' 'ff_no_seen_after_stop' 'flexible']

# %% [markdown]
# ### plot heading

# %% [markdown]
# #### normal

# %%
ps.plot_heading_in_overall_median_info()
# Out:
#
# =========================================================
# Current combination of changeable variables: {'whether_even_out_dist': False}

# %% [markdown]
# #### across_monkeys_and_arc_types

# %%
ps.plot_heading_in_overall_median_info_across_monkeys_and_arc_types()

# %%
# ps.plot_heading_in_overall_median_info_across_monkeys_and_arc_types(
#     x_var_column_list=['key_for_split'],
#                                                                       fixed_variable_values_to_use={
#                                                                                 'if_test_nxt_ff_group_appear_after_stop': 'flexible',
#                                                                                                     #'key_for_split': 'ff_seen',
#                                                                                                     'whether_even_out_dist': False,
#                                                                                                     'curv_traj_window_before_stop': '[-50, 0]'
#                                                                                                     },
#                                                                       changeable_variables=[
#                                                                           'ref_point_value', 'monkey_name'],
#                                                                       columns_to_find_unique_combinations_for_color=['opt_arc_type'],
#                                                                       columns_to_find_unique_combinations_for_line=[],
#                                                                       )

# %% [markdown]
# ### plot curv

# %% [markdown]
# #### normal

# %%
ps.plot_curv_in_overall_median_info()
# Out:
#
# =========================================================
# Current combination of changeable variables: {'whether_even_out_dist': False}

# %% [markdown]
# #### across_monkeys_and_arc_types

# %%
ps.plot_curv_in_overall_median_info_across_monkeys_and_arc_types()

# %%
# ps.plot_curv_in_overall_median_info_across_monkeys_and_arc_types(

#         x_var_column_list=['curv_traj_window_before_stop'],
#                                                                       fixed_variable_values_to_use={
#                                                                                 'if_test_nxt_ff_group_appear_after_stop': 'flexible',
#                                                                                                     'key_for_split': 'ff_seen',
#                                                                                                     'whether_even_out_dist': False,
#                                                                                                     #'curv_traj_window_before_stop': '[-50, 0]'
#                                                                                                     },
#                                                                       changeable_variables=[
#                                                                           'ref_point_value', 'monkey_name', 'opt_arc_type'],
#                                                                       columns_to_find_unique_combinations_for_color=[],
#                                                                       columns_to_find_unique_combinations_for_line=[],
# )

# %%
cma.all_median_info_heading
# Out:
#       Unnamed: 0.1  diff_in_angle_to_nxt_ff_Q1  \
# 0         42.00000                    -7.55153
# 1         43.00000                    -6.35422
# 2         44.00000                    -9.49058
# 3         45.00000                    -6.35422
# 4         46.00000                    -7.73028
# ...            ...                         ...
# 7219           NaN                   -92.38365
# 7220           NaN                    32.93316
# 7221           NaN                   -92.38365
# 7222           NaN                  -103.37180
# 7223           NaN                   -92.38365
#
#       diff_in_abs_angle_to_nxt_ff_Q1  diff_in_abs_d_curv_Q1  \
# 0                           -2.06561               -3.82165
# 1                           -2.64424               -4.50787
# 2                           -2.37941               -3.51095
# 3                           -2.64424               -4.50787
# 4                           -2.09441               -3.78513
# ...                              ...                    ...
# 7219                       -84.15972               -5.66364
# 7220                       -76.33935                    NaN
# 7221                       -84.15972               -5.66364
# 7222                       -93.13196              -10.98304
# 7223                       -84.15972               -5.66364
#
#       diff_in_angle_to_nxt_ff_median  diff_in_abs_angle_to_nxt_ff_median  \
# 0                           -0.28327                             2.54121
# 1                            0.15205                             1.86183
# 2                           -1.12134                             2.08918
# 3                            0.15205                             1.86183
# 4                           -0.35401                             2.53445
# ...                              ...                                 ...
# 7219                         4.96745                           -38.94168
# 7220                       119.30394                           -62.90413
# 7221                         4.96745                           -38.94168
# 7222                         3.96328                           -40.96742
# 7223                         4.96745                           -38.94168
#
#       diff_in_abs_d_curv_median  diff_in_angle_to_nxt_ff_Q3  \
# 0                       1.64149                     6.35079
# 1                       1.03121                     6.16790
# 2                       1.29171                     5.02487
# 3                       1.03121                     6.16790
# 4                       1.52207                     6.19074
# ...                         ...                         ...
# 7219                   11.87891                   103.86500
# 7220                        NaN                   134.51552
# 7221                   11.87891                   103.86500
# 7222                    3.84101                    99.12831
# 7223                   11.87891                   103.86500
#
#       diff_in_abs_angle_to_nxt_ff_Q3  diff_in_abs_d_curv_Q3  ...  \
# 0                            8.90521               10.98273  ...
# 1                            7.66548                8.53119  ...
# 2                            9.75864                9.47021  ...
# 3                            7.66548                8.53119  ...
# 4                            9.01588               10.85175  ...
# ...                              ...                    ...  ...
# 7219                        12.68496               52.86368  ...
# 7220                       -58.17087                    NaN  ...
# 7221                        12.68496               52.86368  ...
# 7222                         3.95091               63.90667  ...
# 7223                        12.68496               52.86368  ...
#
#      if_test_nxt_ff_group_appear_after_stop  \
# 0                   ff_must_seen_after_stop
# 1                   ff_must_seen_after_stop
# 2                     ff_no_seen_after_stop
# 3                     ff_no_seen_after_stop
# 4                                  flexible
# ...                                     ...
# 7219                ff_must_seen_after_stop
# 7220                  ff_no_seen_after_stop
# 7221                  ff_no_seen_after_stop
# 7222                               flexible
# 7223                               flexible
#
#       if_ctrl_nxt_ff_group_appear_after_stop  ctrl_flash_compared_to_test  \
# 0                                   flexible                     flexible
# 1                                   flexible                     flexible
# 2                                   flexible                     flexible
# 3                                   flexible                     flexible
# 4                                   flexible                     flexible
# ...                                      ...                          ...
# 7219                                flexible                     flexible
# 7220                                flexible                     flexible
# 7221                                flexible                     flexible
# 7222                                flexible                     flexible
# 7223                                flexible                     flexible
#
#       max_curv_range             ref_point_mode  ref_point_value  \
# 0                200  time after cur ff visible         -0.20000
# 1                200  time after cur ff visible         -0.20000
# 2                200  time after cur ff visible         -0.20000
# 3                200  time after cur ff visible         -0.20000
# 4                200  time after cur ff visible         -0.20000
# ...              ...                        ...              ...
# 7219             200                   distance       -150.00000
# 7220             200                   distance       -150.00000
# 7221             200                   distance       -150.00000
# 7222             200                   distance       -150.00000
# 7223             200                   distance       -150.00000
#
#       curv_traj_window_before_stop   monkey_name          opt_arc_type  \
# 0                         [-50, 0]  monkey_Schro  opt_arc_stop_closest
# 1                         [-50, 0]  monkey_Schro  opt_arc_stop_closest
# 2                         [-50, 0]  monkey_Schro  opt_arc_stop_closest
# 3                         [-50, 0]  monkey_Schro  opt_arc_stop_closest
# 4                         [-50, 0]  monkey_Schro  opt_arc_stop_closest
# ...                            ...           ...                   ...
# 7219                      [-50, 0]         agent  opt_arc_stop_closest
# 7220                      [-50, 0]         agent  opt_arc_stop_closest
# 7221                      [-50, 0]         agent  opt_arc_stop_closest
# 7222                      [-50, 0]         agent  opt_arc_stop_closest
# 7223                      [-50, 0]         agent  opt_arc_stop_closest
#
#       monkey_or_agent
# 0              monkey
# 1              monkey
# 2              monkey
# 3              monkey
# 4              monkey
# ...               ...
# 7219            agent
# 7220            agent
# 7221            agent
# 7222            agent
# 7223            agent
#
# [7224 rows x 32 columns]

# %%
ps.all_median_info_heading
# Out:
#       Unnamed: 0.1  diff_in_angle_to_nxt_ff_Q1  \
# 0                0                    -7.44335
# 1                1                    -6.38417
# 2                2                    -9.01486
# 3                3                    -6.38417
# 4                4                    -7.60400
# ...            ...                         ...
# 1507           247                    -6.29449
# 1508           248                    -7.65778
# 1509           249                    -6.29449
# 1510           250                    -7.12858
# 1511           251                    -6.29449
#
#       diff_in_abs_angle_to_nxt_ff_Q1  diff_in_abs_d_curv_Q1  \
# 0                           -2.17240               -3.29672
# 1                           -2.67819               -4.48419
# 2                           -2.72574               -3.27968
# 3                           -2.67819               -4.48419
# 4                           -2.19412               -3.29672
# ...                              ...                    ...
# 1507                        -6.03843              -12.48838
# 1508                        -3.74338               -9.85197
# 1509                        -6.03843              -12.48838
# 1510                        -4.56425              -11.81301
# 1511                        -6.03843              -12.48838
#
#       diff_in_angle_to_nxt_ff_median  diff_in_abs_angle_to_nxt_ff_median  \
# 0                           -0.34454                             2.54080
# 1                            0.32104                             1.82326
# 2                           -1.16733                             2.16293
# 3                            0.32104                             1.82326
# 4                           -0.38946                             2.47642
# ...                              ...                                 ...
# 1507                         4.95155                             3.07013
# 1508                         6.53791                             6.03602
# 1509                         4.95155                             3.07013
# 1510                         5.65604                             4.76469
# 1511                         4.95155                             3.07013
#
#       diff_in_abs_d_curv_median  diff_in_angle_to_nxt_ff_Q3  \
# 0                       1.74775                     6.37974
# 1                       1.03666                     6.22697
# 2                       1.72317                     5.24414
# 3                       1.03666                     6.22697
# 4                       1.74775                     6.27721
# ...                         ...                         ...
# 1507                    0.61546                    14.90284
# 1508                    4.28087                    17.52229
# 1509                    0.61546                    14.90284
# 1510                    2.18635                    16.13980
# 1511                    0.61546                    14.90284
#
#       diff_in_abs_angle_to_nxt_ff_Q3  diff_in_abs_d_curv_Q3  ...  \
# 0                            8.54044               10.57500  ...
# 1                            7.39004                8.42059  ...
# 2                            8.79569                9.42572  ...
# 3                            7.39004                8.42059  ...
# 4                            8.57200               10.47401  ...
# ...                              ...                    ...  ...
# 1507                        12.62016               15.67339  ...
# 1508                        16.63939               27.63529  ...
# 1509                        12.62016               15.67339  ...
# 1510                        14.63220               21.21935  ...
# 1511                        12.62016               15.67339  ...
#
#      whether_limit_cur_ff_cluster_50_size  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 1507                                False
# 1508                                False
# 1509                                False
# 1510                                False
# 1511                                False
#
#       if_test_nxt_ff_group_appear_after_stop  \
# 0                    ff_must_seen_after_stop
# 1                    ff_must_seen_after_stop
# 2                      ff_no_seen_after_stop
# 3                      ff_no_seen_after_stop
# 4                                   flexible
# ...                                      ...
# 1507                 ff_must_seen_after_stop
# 1508                   ff_no_seen_after_stop
# 1509                   ff_no_seen_after_stop
# 1510                                flexible
# 1511                                flexible
#
#       if_ctrl_nxt_ff_group_appear_after_stop  ctrl_flash_compared_to_test  \
# 0                                   flexible                     flexible
# 1                                   flexible                     flexible
# 2                                   flexible                     flexible
# 3                                   flexible                     flexible
# 4                                   flexible                     flexible
# ...                                      ...                          ...
# 1507                                flexible                     flexible
# 1508                                flexible                     flexible
# 1509                                flexible                     flexible
# 1510                                flexible                     flexible
# 1511                                flexible                     flexible
#
#       max_curv_range             ref_point_mode  ref_point_value  \
# 0                200  time after cur ff visible         -0.20000
# 1                200  time after cur ff visible         -0.20000
# 2                200  time after cur ff visible         -0.20000
# 3                200  time after cur ff visible         -0.20000
# 4                200  time after cur ff visible         -0.20000
# ...              ...                        ...              ...
# 1507             200                   distance       -150.00000
# 1508             200                   distance       -150.00000
# 1509             200                   distance       -150.00000
# 1510             200                   distance       -150.00000
# 1511             200                   distance       -150.00000
#
#       curv_traj_window_before_stop   monkey_name                 opt_arc_type
# 0                         [-25, 0]  monkey_Schro                 norm_opt_arc
# 1                         [-25, 0]  monkey_Schro                 norm_opt_arc
# 2                         [-25, 0]  monkey_Schro                 norm_opt_arc
# 3                         [-25, 0]  monkey_Schro                 norm_opt_arc
# 4                         [-25, 0]  monkey_Schro                 norm_opt_arc
# ...                            ...           ...                          ...
# 1507                      [-75, 0]  monkey_Bruno  opt_arc_stop_first_vis_bdry
# 1508                      [-75, 0]  monkey_Bruno  opt_arc_stop_first_vis_bdry
# 1509                      [-75, 0]  monkey_Bruno  opt_arc_stop_first_vis_bdry
# 1510                      [-75, 0]  monkey_Bruno  opt_arc_stop_first_vis_bdry
# 1511                      [-75, 0]  monkey_Bruno  opt_arc_stop_first_vis_bdry
#
# [1512 rows x 31 columns]

# %% [markdown]
# ### compare (monkey and agent)

# %%
cma = cmp_monkey_agent_plan_class.CompareMonkeyAgentPlan()
cma.get_monkey_and_agent_overall_median_info()
# Out:
# Successfully retrieved overall_median_info from  RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/combined_data/cur_and_nxt/data_comparison/opt_arc_stop_closest/overall_median_info.csv
# Saved overall_median_info_path to RL_models/SB3_stored_models/all_collected_data/planning/env1_relu/ff3/dv10_dw10_w10_mem3/combined_data/cur_and_nxt/data_comparison/opt_arc_stop_closest/overall_median_info.csv
# Columns (among selected ones for examination) that have variations:
# ===================================================
#
# test_or_control ['test' 'control']
# ===================================================
#
# monkey_or_agent ['monkey' 'agent']
# ===================================================
#
# ref_point_value [  -0.2   -0.1    0.     0.1    0.2 -100.  -150. ]
# ===================================================
#
# if_test_nxt_ff_group_appear_after_stop ['ff_must_seen_after_stop' 'ff_no_seen_after_stop' 'flexible']
# ===================================================
#
# monkey_name ['monkey_Schro' 'monkey_Bruno' 'agent']

# %% [markdown]
# #### heading

# %%
x_var_column_list = ['monkey_name']
fixed_variable_values_to_use = {#'whether_even_out_dist': True,
                                'if_test_nxt_ff_group_appear_after_stop': 'flexible',
                                'key_for_split': 'ff_seen',
                                }
changeable_variables = ['ref_point_value']
columns_to_find_unique_combinations_for_color = []

cma.plot_heading_in_overall_median_info_across_monkeys_and_arc_types(x_var_column_list=x_var_column_list,
                                                                fixed_variable_values_to_use=fixed_variable_values_to_use,
                                                                changeable_variables=changeable_variables,
                                                                columns_to_find_unique_combinations_for_color=columns_to_find_unique_combinations_for_color)

# %% [markdown]
# #### curv

# %%
x_var_column_list = ['monkey_name']
fixed_variable_values_to_use = {'whether_even_out_dist': True,
                                'if_test_nxt_ff_group_appear_after_stop': 'flexible',
                                'key_for_split': 'ff_seen',
                                }
changeable_variables = ['ref_point_value']
columns_to_find_unique_combinations_for_color = []

cma.plot_curv_in_overall_median_info_across_monkeys_and_arc_types(x_var_column_list=x_var_column_list,
                                                                fixed_variable_values_to_use=fixed_variable_values_to_use,
                                                                changeable_variables=changeable_variables,
                                                                columns_to_find_unique_combinations_for_color=columns_to_find_unique_combinations_for_color)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 9
#       6 changeable_variables = ['ref_point_value']
#       7 columns_to_find_unique_combinations_for_color = []
# ----> 9 cma.plot_curv_in_overall_median_info_across_monkeys_and_arc_types(x_var_column_list=x_var_column_list,
#      10                                                                 fixed_variable_values_to_use=fixed_variable_values_to_use,
#      11                                                                 changeable_variables=changeable_variables,
#      12                                                                 columns_to_find_unique_combinations_for_color=columns_to_find_unique_combinations_for_color)
#
# NameError: name 'cma' is not defined

# %% [markdown]
# ### flexibly change plotting parameters

# %%
x_var_column_list = ['ref_point_value']

fixed_variable_values_to_use = {
                                #'whether_even_out_dist': True
                                # 'max_curv_range': 200,
                                # 'whether_filter_info': True,
                                'if_test_nxt_ff_group_appear_after_stop': 'flexible',
                                'key_for_split': 'ff_seen',
                                #'whether_even_out_dist': False,
}

changeable_variables = ['whether_even_out_dist']


columns_to_find_unique_combinations_for_color = []
columns_to_find_unique_combinations_for_line = []


ps.plot_heading_in_overall_median_info(x_var_column_list=x_var_column_list, 
                                           fixed_variable_values_to_use=fixed_variable_values_to_use,
                                           changeable_variables=changeable_variables,
                                           columns_to_find_unique_combinations_for_color=columns_to_find_unique_combinations_for_color,
                                           columns_to_find_unique_combinations_for_line=columns_to_find_unique_combinations_for_line,
                                           )

# %% [markdown]
# ## all_perc_info

# %% [markdown]
# ### monkey

# %% [markdown]
# #### combine monkey and arc type

# %%
ps = monkey_plan_factors_x_sess_class.PlanAcrossSessions()
# combine both monkeys
monkey_perc_df = ps.combine_all_perc_info_across_monkeys()
# Out:
# Columns (among selected ones for examination) that have variations:
# ===================================================
#
# test_or_control ['test' 'control']
# ===================================================
#
# if_test_nxt_ff_group_appear_after_stop ['ff_must_seen_after_stop' 'ff_no_seen_after_stop' 'flexible']
# ===================================================
#
# monkey_name ['monkey_Bruno' 'monkey_Schro']

# %% [markdown]
# #### for individual monkey, and one arc type

# %%
ps = monkey_plan_factors_x_sess_class.PlanAcrossSessions(monkey_name='monkey_Bruno')
monkey_perc_df = ps.make_or_retrieve_all_perc_info(exists_ok=True)

# %%
ps = monkey_plan_factors_x_sess_class.PlanAcrossSessions(monkey_name='monkey_Schro')
monkey_perc_df = ps.make_or_retrieve_all_perc_info(exists_ok=True)

# %% [markdown]
# ### agent

# %%
pfas = agent_plan_factors_x_sess_class.PlanFactorsAcrossAgentSessions()
agent_all_perc_df = pfas.make_or_retrieve_all_perc_info(exists_ok=True)

# %% [markdown]
# ### plot dir

# %% [markdown]
# #### normal

# %%
ps.plot_direction_in_all_perc_info()

# %% [markdown]
# #### across_monkeys_and_arc_types

# %%
ps.plot_direction_in_all_perc_info_across_monkeys()

# %% [markdown]
# ### compare (monkey and agent)

# %%
cma = cmp_monkey_agent_plan_class.CompareMonkeyAgentPlan()
cma.get_monkey_and_agent_all_perc_info()

# %%
x_var_column_list = ['monkey_name']

fixed_variable_values_to_use = {#'whether_even_out_dist': False,
                                'if_test_nxt_ff_group_appear_after_stop': 'flexible',
                                'key_for_split': 'ff_seen',
                                }

changeable_variables = [] #'if_test_nxt_ff_group_appear_after_stop'

columns_to_find_unique_combinations_for_color = []

cma.plot_direction_in_all_perc_info_across_monkeys(x_var_column_list=x_var_column_list,
                                                                fixed_variable_values_to_use=fixed_variable_values_to_use,
                                                                changeable_variables=changeable_variables,
                                                                columns_to_find_unique_combinations_for_color=columns_to_find_unique_combinations_for_color)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 12
#       8 changeable_variables = [] #'if_test_nxt_ff_group_appear_after_stop'
#      10 columns_to_find_unique_combinations_for_color = []
# ---> 12 cma.plot_direction_in_all_perc_info_across_monkeys(x_var_column_list=x_var_column_list,
#      13                                                                 fixed_variable_values_to_use=fixed_variable_values_to_use,
#      14                                                                 changeable_variables=changeable_variables,
#      15                                                                 columns_to_find_unique_combinations_for_color=columns_to_find_unique_combinations_for_color)
#
# File ~/Documents/Multifirefly-Project/multiff_analysis/multiff_code/methods/planning_analysis/variations_of_factors_vs_results/_plot_variations_class.py:144, in _PlotVariations.plot_direction_in_all_perc_info_across_monkeys(self, x_var_column_list, fixed_variable_values_to_use, changeable_variables, columns_to_find_unique_combinations_for_color)
#     134 def plot_direction_in_all_perc_info_across_monkeys(self,
#     135                                                    x_var_column_list=[
#     136                                                        'monkey_name'],
#    (...)    141                                                    changeable_variables=[],  # 'key_for_split'
#     142                                                    columns_to_find_unique_combinations_for_color=[]):
# --> 144     self.plot_direction_in_all_perc_info(x_var_column_list=x_var_column_list,
#     145                                          fixed_variable_values_to_use=fixed_variable_values_to_use,
#     146                                          changeable_variables=changeable_variables,
#     147                                          columns_to_find_unique_combinations_for_color=columns_to_find_unique_combinations_for_color,
#     148                                          add_error_bars=True,
#     149                                          use_subplots_based_on_changeable_variables=True)
#
# File ~/Documents/Multifirefly-Project/multiff_analysis/multiff_code/methods/planning_analysis/variations_of_factors_vs_results/_plot_variations_class.py:123, in _PlotVariations.plot_direction_in_all_perc_info(self, x_var_column_list, fixed_variable_values_to_use, changeable_variables, columns_to_find_unique_combinations_for_color, add_error_bars, use_subplots_based_on_changeable_variables)
#     111 def plot_direction_in_all_perc_info(self,
#     112                                     x_var_column_list=['key_for_split'],
#     113                                     fixed_variable_values_to_use={
#    (...)    118                                     add_error_bars=False,
#     119                                     use_subplots_based_on_changeable_variables=False):
#     121     se_column = 'perc_se' if add_error_bars else None
# --> 123     plot_variations_utils.streamline_making_plotly_plot_to_compare_two_sets_of_data(self.all_perc_info_new,
#     124                                                                                     fixed_variable_values_to_use,
#     125                                                                                     changeable_variables,
#     126                                                                                     x_var_column_list,
#     127                                                                                     y_var_column='perc',
#     128                                                                                     se_column=se_column,
#     129                                                                                     var_to_determine_x_offset_direction='test_or_control',
#     130                                                                                     columns_to_find_unique_combinations_for_color=columns_to_find_unique_combinations_for_color,
#     131                                                                                     use_subplots_based_on_changeable_variables=use_subplots_based_on_changeable_variables
#     132                                                                                     )
#
# AttributeError: 'CompareMonkeyAgentPlan' object has no attribute 'all_perc_info_new'

# %%
STOP!

# %% [markdown]
# # LR variations

# %% [markdown]
# ## all_cur_and_nxt_lr_df (pred monkey)

# %% [markdown]
# ### MONKEY

# %%
ps = monkey_plan_factors_x_sess_class.PlanAcrossSessions(monkey_name='monkey_Bruno')
all_cur_and_nxt_lr_df = ps.make_or_retrieve_all_cur_and_nxt_lr_df(exists_ok=True)
monkey_pred_monkey_df = all_cur_and_nxt_lr_df.copy()

# %%
ps = monkey_plan_factors_x_sess_class.PlanAcrossSessions(monkey_name='monkey_Schro')
all_cur_and_nxt_lr_df = ps.make_or_retrieve_all_cur_and_nxt_lr_df(exists_ok=True)
monkey_pred_monkey_df = all_cur_and_nxt_lr_df.copy()

# %%
new_all_cur_and_nxt_lr_df = process_variations_utils.make_new_df_for_plotly_comparison(all_cur_and_nxt_lr_df)

# %%
x_var_column_list = ['ref_point_value']


fixed_variable_values_to_use = {
                                'cluster_for_interaction': 'cur_ff_cluster_100',
                                'cluster_to_keep': 'cur_ff_cluster_100',
                                #'cluster_to_keep': 'cur_ff_cluster_100_PLUS_nxt_ff_cluster_100_PLUS_nxt_ff_cluster_300',
                                #'use_combd_features_for_cluster_only': False,
                                'key_for_split': 'ff_seen',
                                'whether_even_out_dist': False,
}

changeable_variables = ['y_var_column']

columns_to_find_unique_combinations_for_color = ['test_or_control']

plot_variations_utils.streamline_making_plotly_plot_to_compare_two_sets_of_data(new_all_cur_and_nxt_lr_df, 
                                                              fixed_variable_values_to_use,
                                                              changeable_variables,
                                                              x_var_column_list,
                                                              columns_to_find_unique_combinations_for_color=columns_to_find_unique_combinations_for_color)

# %% [markdown]
# ### AGENT

# %%
(75 + 94.5 + 86.5 + 98)/4

# %%
pfas =agent_plan_factors_x_sess_class.PlanFactorsAcrossAgentSessions()
all_cur_and_nxt_lr_df = pfas.make_or_retrieve_all_cur_and_nxt_lr_df()
agent_pred_ff_df = all_cur_and_nxt_lr_df.copy()

# %%
new_all_cur_and_nxt_lr_df = process_variations_utils.make_new_df_for_plotly_comparison(all_cur_and_nxt_lr_df)

# %%
x_var_column_list = ['ref_point_value']

fixed_variable_values_to_use = {'cluster_for_interaction': 'cur_ff_cluster_100',
                                'cluster_to_keep': 'cur_ff_cluster_100_PLUS_nxt_ff_cluster_100',
                                'use_combd_features_for_cluster_only': False,
}

changeable_variables = ['y_var_column', 'whether_even_out_dist', 'key_for_split'] #'ref_point_value'


columns_to_find_unique_combinations_for_color = ['test_or_control']

plot_variations_utils.streamline_making_plotly_plot_to_compare_two_sets_of_data(new_all_cur_and_nxt_lr_df, 
                                                              fixed_variable_values_to_use,
                                                              changeable_variables,
                                                              x_var_column_list,
                                                              columns_to_find_unique_combinations_for_color=columns_to_find_unique_combinations_for_color)

# %% [markdown]
# ### plot coeff (individually)

# %%
new_all_cur_and_nxt_lr_df

# %%
fixed_variable_values_to_use = {'cluster_for_interaction': 'cur_ff_cluster_100',
                                'cluster_to_keep': 'cur_ff_cluster_100_PLUS_nxt_ff_cluster_100_PLUS_nxt_ff_cluster_300',
                                'use_combd_features_for_cluster_only': False,
                                #'whether_even_out_dist': True,
}

column_to_split_grouped_bars = 'test_or_control'

plot_variations_utils.plot_coeff(new_all_cur_and_nxt_lr_df, column_to_split_grouped_bars=column_to_split_grouped_bars, fixed_variable_values_to_use=fixed_variable_values_to_use,
                                 max_num_plots=3)

# %% [markdown]
# ### compare monkey and agent

# %% [markdown]
# #### get data

# %%
both_players_pred_monkey_df = compare_monkey_and_agent_utils.make_both_players_df(monkey_pred_monkey_df, agent_pred_monkey_df)

# %% [markdown]
# #### r squared

# %%
# print columns in ref_sub2.columns if no numeric is in the string
# ref_sub2.columns[~ref_sub2.columns.str.contains('\d')]

# %%
new_pred_monkey_df = process_variations_utils.make_new_df_for_plotly_comparison(both_players_pred_monkey_df,
                                                                 match_rows_based_on_ref_columns_only=True)

# %%
x_var_column_list = ['ref_point_value']

fixed_variable_values_to_use = {
                                # 'cluster_for_interaction': 'none',
                                # 'cluster_to_keep': 'none',
                                'cluster_to_keep': 'cur_ff_cluster_100_PLUS_nxt_ff_cluster_100_PLUS_nxt_ff_cluster_300',
                                'cluster_for_interaction': 'none',
                                'whether_even_out_dist': True,
                                #'use_combd_features_for_cluster_only': False,
}

changeable_variables = ['y_var_column'] #'ref_point_value'


columns_to_find_unique_combinations_for_color = ['test_or_control']
columns_to_find_unique_combinations_for_line = ['monkey_or_agent']

plot_variations_utils.streamline_making_plotly_plot_to_compare_two_sets_of_data(new_pred_monkey_df, 
                                                              fixed_variable_values_to_use,
                                                              changeable_variables,
                                                              x_var_column_list,
                                                              var_to_determine_x_offset_direction='ref_columns_only',
                                                              columns_to_find_unique_combinations_for_color=columns_to_find_unique_combinations_for_color,
                                                              columns_to_find_unique_combinations_for_line=columns_to_find_unique_combinations_for_line)

# %% [markdown]
# #### coeff

# %%
both_players_df['ref_columns_only']

# %%
fixed_variable_values_to_use = {
                                #'cluster_for_interaction': 'none',
                                #'cluster_to_keep': 'cur_ff_cluster_100_PLUS_nxt_ff_cluster_100_PLUS_nxt_ff_cluster_300',
                                'ref_columns_only': True
}

column_to_split_grouped_bars = 'monkey_or_agent'

plot_variations_utils.plot_coeff(both_players_df, column_to_split_grouped_bars=column_to_split_grouped_bars, fixed_variable_values_to_use=fixed_variable_values_to_use)

# %% [markdown]
# ## all_cur_and_nxt_lr_pred_ff_df (pred ff)

# %% [markdown]
# ### MONKEY

# %%
ps = monkey_plan_factors_x_sess_class.PlanAcrossSessions(monkey_name='monkey_Bruno')
all_cur_and_nxt_lr_pred_ff_df = ps.make_or_retrieve_all_cur_and_nxt_lr_pred_ff_df()
monkey_pred_ff_df = all_cur_and_nxt_lr_pred_ff_df.copy()

# %%
ps = monkey_plan_factors_x_sess_class.PlanAcrossSessions(monkey_name='monkey_Schro')
all_cur_and_nxt_lr_pred_ff_df = ps.make_or_retrieve_all_cur_and_nxt_lr_pred_ff_df()
monkey_pred_ff_df = all_cur_and_nxt_lr_pred_ff_df.copy()

# %%
new_all_cur_and_nxt_lr_pred_ff_df = process_variations_utils.make_new_df_for_plotly_comparison(all_cur_and_nxt_lr_pred_ff_df)

# %%
x_var_column_list = ['ref_point_value']

fixed_variable_values_to_use = {
                                #'key_for_split': 'cluster_seen'
}

changeable_variables = ['y_var_column', 'whether_even_out_dist']


columns_to_find_unique_combinations_for_color = ['test_or_control']

plot_variations_utils.streamline_making_plotly_plot_to_compare_two_sets_of_data(new_all_cur_and_nxt_lr_pred_ff_df, 
                                                              fixed_variable_values_to_use,
                                                              changeable_variables,
                                                              x_var_column_list,
                                                              columns_to_find_unique_combinations_for_color=columns_to_find_unique_combinations_for_color)

# %%
all_cur_and_nxt_lr_pred_ff_df['sample_size'] = all_cur_and_nxt_lr_pred_ff_df['ctrl_sample_size']
all_cur_and_nxt_lr_pred_ff_df.loc[all_cur_and_nxt_lr_pred_ff_df['test_or_control']=='test', 'sample_size'] = all_cur_and_nxt_lr_pred_ff_df['test_sample_size']
#all_cur_and_nxt_lr_pred_ff_df.loc[all_cur_and_nxt_lr_pred_ff_df['cluster_for_interaction'].isnull(), 'cluster_for_interaction'] = 'null'

# %%
stop

# %% [markdown]
# ### AGENT

# %%
pfas =agent_plan_factors_x_sess_class.PlanFactorsAcrossAgentSessions()
all_cur_and_nxt_lr_pred_ff_df = pfas.make_or_retrieve_all_cur_and_nxt_lr_pred_ff_df()
agent_pred_ff_df = all_cur_and_nxt_lr_pred_ff_df.copy()

# %%
new_all_cur_and_nxt_lr_pred_ff_df = process_variations_utils.make_new_df_for_plotly_comparison(all_cur_and_nxt_lr_pred_ff_df)

# %%
x_var_column_list = ['ref_point_value']

fixed_variable_values_to_use = {
}

changeable_variables = ['y_var_column', 'key_for_split', 'whether_even_out_dist']


columns_to_find_unique_combinations_for_color = ['test_or_control']

plot_variations_utils.streamline_making_plotly_plot_to_compare_two_sets_of_data(new_all_cur_and_nxt_lr_pred_ff_df, 
                                                              fixed_variable_values_to_use,
                                                              changeable_variables,
                                                              x_var_column_list,
                                                              columns_to_find_unique_combinations_for_color=columns_to_find_unique_combinations_for_color)

# %%
all_cur_and_nxt_lr_pred_ff_df['sample_size'] = all_cur_and_nxt_lr_pred_ff_df['ctrl_sample_size']
all_cur_and_nxt_lr_pred_ff_df.loc[all_cur_and_nxt_lr_pred_ff_df['test_or_control']=='test', 'sample_size'] = all_cur_and_nxt_lr_pred_ff_df['test_sample_size']
#all_cur_and_nxt_lr_pred_ff_df.loc[all_cur_and_nxt_lr_pred_ff_df['cluster_for_interaction'].isnull(), 'cluster_for_interaction'] = 'null'

# %% [markdown]
# ### compare monkey and agent

# %% [markdown]
# #### get data

# %%
both_pred_ff_players_df = compare_monkey_and_agent_utils.make_both_players_df(monkey_pred_ff_df, agent_pred_ff_df)

# %% [markdown]
# #### r squared

# %%
# print columns in ref_sub2.columns if no numeric is in the string
# ref_sub2.columns[~ref_sub2.columns.str.contains('\d')]

# %%
new_pred_ff_df = process_variations_utils.make_new_df_for_plotly_comparison(both_pred_ff_players_df,
                                                                 match_rows_based_on_ref_columns_only=True)

# %%
x_var_column_list = ['ref_point_value']

fixed_variable_values_to_use = {'whether_even_out_dist': True,
                                #'key_for_split': 'cluster_seen',
}

changeable_variables = ['y_var_column', 'key_for_split'] #'ref_point_value'


columns_to_find_unique_combinations_for_color = ['test_or_control']
columns_to_find_unique_combinations_for_line = ['monkey_or_agent']

plot_variations_utils.streamline_making_plotly_plot_to_compare_two_sets_of_data(new_pred_ff_df, 
                                                              fixed_variable_values_to_use,
                                                              changeable_variables,
                                                              x_var_column_list,
                                                              var_to_determine_x_offset_direction='ref_columns_only',
                                                              columns_to_find_unique_combinations_for_color=columns_to_find_unique_combinations_for_color,
                                                              columns_to_find_unique_combinations_for_line=columns_to_find_unique_combinations_for_line)

# %% [markdown]
# #### coeff

# %%
both_players_pred_ff_df['ref_columns_only']

# %%
fixed_variable_values_to_use = {
                                #'cluster_for_interaction': 'none',
                                #'cluster_to_keep': 'cur_ff_cluster_100_PLUS_nxt_ff_cluster_100_PLUS_nxt_ff_cluster_300',
                                'ref_columns_only': True
}

column_to_split_grouped_bars = 'monkey_or_agent'

plot_variations_utils.plot_coeff(both_players_pred_ff_df, column_to_split_grouped_bars=column_to_split_grouped_bars, fixed_variable_values_to_use=fixed_variable_values_to_use)

# %% [markdown]
# ## all_cur_and_nxt_clf_df

# %% [markdown]
# ### MONKEY

# %%
ps = monkey_plan_factors_x_sess_class.PlanAcrossSessions(monkey_name='monkey_Bruno')
all_cur_and_nxt_clf_df = ps.make_or_retrieve_all_cur_and_nxt_clf_df()
monkey_clf_df = all_cur_and_nxt_clf_df.copy()

# %%
ps = monkey_plan_factors_x_sess_class.PlanAcrossSessions(monkey_name='monkey_Schro')
all_cur_and_nxt_clf_df = ps.make_or_retrieve_all_cur_and_nxt_clf_df()
monkey_clf_df = all_cur_and_nxt_clf_df.copy()

# %%
new_all_cur_and_nxt_clf_df = process_variations_utils.make_new_df_for_plotly_comparison(all_cur_and_nxt_clf_df)

# %%
x_var_column_list = ['ref_point_value']

fixed_variable_values_to_use = {'cluster_for_interaction': 'cur_ff_cluster_100',
                                'cluster_to_keep': 'cur_ff_cluster_100_PLUS_nxt_ff_cluster_100',
                                'use_combd_features_for_cluster_only': False,
                                #'whether_even_out_dist': True,
}

changeable_variables = ['y_var_column', 'whether_even_out_dist', 'key_for_split']


columns_to_find_unique_combinations_for_color = ['test_or_control']

plot_variations_utils.streamline_making_plotly_plot_to_compare_two_sets_of_data(new_all_cur_and_nxt_clf_df, 
                                                              fixed_variable_values_to_use,
                                                              changeable_variables,
                                                              x_var_column_list,
                                                              y_var_column='average_accuracy',
                                                              columns_to_find_unique_combinations_for_color=columns_to_find_unique_combinations_for_color)

# %% [markdown]
# ### AGENT

# %%
pfas =agent_plan_factors_x_sess_class.PlanFactorsAcrossAgentSessions()
all_cur_and_nxt_clf_df = pfas.make_or_retrieve_all_cur_and_nxt_clf_df()
agent_pred_ff_df = all_cur_and_nxt_clf_df.copy()

# %%
new_all_cur_and_nxt_clf_df = process_variations_utils.make_new_df_for_plotly_comparison(all_cur_and_nxt_clf_df)

# %%
x_var_column_list = ['ref_point_value']

fixed_variable_values_to_use = {
                                # 'cluster_for_interaction': 'cur_ff_cluster_100',
                                # 'cluster_to_keep': 'cur_ff_cluster_100_PLUS_nxt_ff_cluster_100',
                                'cluster_to_keep': 'none',
                                'use_combd_features_for_cluster_only': False,
                                #'whether_even_out_dist': True,
}

changeable_variables = ['y_var_column', 'whether_even_out_dist', 'key_for_split']


columns_to_find_unique_combinations_for_color = ['test_or_control']

plot_variations_utils.streamline_making_plotly_plot_to_compare_two_sets_of_data(new_all_cur_and_nxt_clf_df, 
                                                              fixed_variable_values_to_use,
                                                              changeable_variables,
                                                              x_var_column_list,
                                                              y_var_column='average_accuracy',
                                                              columns_to_find_unique_combinations_for_color=columns_to_find_unique_combinations_for_color)

# %% [markdown]
# ### compare monkey and agent

# %% [markdown]
# #### get data

# %%
both_players_clf_df = compare_monkey_and_agent_utils.make_both_players_df(monkey_clf_df, agent_clf_df)

# %% [markdown]
# #### r squared

# %%
# print columns in ref_sub2.columns if no numeric is in the string
# ref_sub2.columns[~ref_sub2.columns.str.contains('\d')]

# %%
new_clf_df = process_variations_utils.make_new_df_for_plotly_comparison(both_players_clf_df,
                                                                 match_rows_based_on_ref_columns_only=True)

# %%
x_var_column_list = ['ref_point_value']

fixed_variable_values_to_use = {
                                'cluster_to_keep': 'cur_ff_cluster_100_PLUS_nxt_ff_cluster_100',
                                'cluster_for_interaction': 'cur_ff_cluster_100',
                                # 'cluster_for_interaction': 'none',
                                # 'cluster_to_keep': 'none',
                                'whether_even_out_dist': True,
                                'key_for_split': 'cluster_seen',
                                #'use_combd_features_for_cluster_only': False,
}

changeable_variables = ['y_var_column', 'cluster_to_keep'] #'ref_point_value'


columns_to_find_unique_combinations_for_color = ['test_or_control']
columns_to_find_unique_combinations_for_line = ['monkey_or_agent']

plot_variations_utils.streamline_making_plotly_plot_to_compare_two_sets_of_data(new_clf_df, 
                                                              fixed_variable_values_to_use,
                                                              changeable_variables,
                                                              x_var_column_list,
                                                              y_var_column='average_accuracy',
                                                              var_to_determine_x_offset_direction='ref_columns_only',
                                                              columns_to_find_unique_combinations_for_color=columns_to_find_unique_combinations_for_color,
                                                              columns_to_find_unique_combinations_for_line=columns_to_find_unique_combinations_for_line)

# %% [markdown]
# #### coeff

# %%
both_players_df['ref_columns_only']

# %%
fixed_variable_values_to_use = {
                                #'cluster_for_interaction': 'none',
                                #'cluster_to_keep': 'cur_ff_cluster_100_PLUS_nxt_ff_cluster_100_PLUS_nxt_ff_cluster_300',
                                'ref_columns_only': True
}

column_to_split_grouped_bars = 'monkey_or_agent'

plot_variations_utils.plot_coeff(both_players_df, column_to_split_grouped_bars=column_to_split_grouped_bars, fixed_variable_values_to_use=fixed_variable_values_to_use)

# %% [markdown]
# ## all_only_cur_lr_df

# %% [markdown]
# ### make df

# %%
exists_ok = True
osfxs = only_cur_ff_x_sess_class.OnlyStopFFAcrossSessions(monkey_name='monkey_Bruno')
all_only_cur_lr_df = osfxs.make_or_retrieve_all_only_cur_lr_df(exists_ok=exists_ok)

# %%
exists_ok = True
osfxs = only_cur_ff_x_sess_class.OnlyStopFFAcrossSessions(monkey_name='monkey_Schro')
all_only_cur_lr_df = osfxs.make_or_retrieve_all_only_cur_lr_df(exists_ok=exists_ok)

# %% [markdown]
# ### plot

# %%
new_all_only_cur_lr_df = process_variations_utils.make_new_df_for_plotly_comparison(all_only_cur_lr_df)

# %%
x_var_column_list = ['ref_point_value']

fixed_variable_values_to_use = {'cluster_for_interaction': 'cur_ff_cluster_100',
                                'add_ref_interaction': True,
                                #'use_combd_features_for_cluster_only': False,
}

changeable_variables = ['y_var_column']


columns_to_find_unique_combinations_for_color = ['add_ref_interaction']

plot_variations_utils.streamline_making_plotly_plot_to_compare_two_sets_of_data(new_all_only_cur_lr_df, 
                                                              fixed_variable_values_to_use,
                                                              changeable_variables,
                                                              x_var_column_list,
                                                              columns_to_find_unique_combinations_for_color=columns_to_find_unique_combinations_for_color)

# %% [markdown]
# ## all_only_cur_ml_df

# %% [markdown]
# ### make df

# %%
osfxs =only_cur_ff_x_sess_class.OnlyStopFFAcrossSessions(monkey_name='monkey_Bruno')
all_only_cur_ml_df = osfxs.make_or_retrieve_all_only_cur_ml_df()

# %%
osfxs =only_cur_ff_x_sess_class.OnlyStopFFAcrossSessions(monkey_name='monkey_Schro')
all_only_cur_ml_df = osfxs.make_or_retrieve_all_only_cur_ml_df()

# %% [markdown]
# ### plot

# %%
new_all_only_cur_ml_df = process_variations_utils.make_new_df_for_plotly_comparison(all_only_cur_ml_df)

# %%
x_var_column_list = ['ref_point_value']

fixed_variable_values_to_use = {'cluster_for_interaction': 'cur_ff_cluster_100',
                                'add_ref_interaction': True,
                                #'use_combd_features_for_cluster_only': False,
}

changeable_variables = ['y_var_column']


columns_to_find_unique_combinations_for_color = ['add_ref_interaction']

plot_variations_utils.streamline_making_plotly_plot_to_compare_two_sets_of_data(new_all_only_cur_ml_df, 
                                                              fixed_variable_values_to_use,
                                                              changeable_variables,
                                                              x_var_column_list,
                                                              columns_to_find_unique_combinations_for_color=columns_to_find_unique_combinations_for_color)

# %% [markdown]
# # Coeff of one comdo

# %% [markdown]
# ### existing

# %%
processed_df = new_all_cur_and_nxt_lr_df.copy()

processed_df = processed_df[processed_df['cluster_for_interaction']=='cur_ff_cluster_100'].copy()

processed_df = processed_df[processed_df['use_combd_features_for_cluster_only']==True].copy()

# those vars can be explanatory vars
processed_df = processed_df[processed_df['keep_monkey_info']==True].copy()
#processed_df = processed_df[processed_df['cluster_to_keep']=='all'].copy()
processed_df = processed_df[processed_df['whether_even_out_dist']==True].copy()

# %%
processed_df = processed_df[processed_df['ref_point_value']==0.1].copy()
processed_df = processed_df[processed_df['cluster_to_keep']=='all'].copy()
processed_df = processed_df[processed_df['ref_columns_only']==False].copy()
processed_df = processed_df[processed_df['y_var_column']=='diff_in_abs_angle_to_nxt_ff'].copy()

# %%
all_features_df = process_variations_utils.make_all_features_df_by_separating_based_on_a_column(processed_df)

# %%
all_features_df_sub = all_features_df[all_features_df['rank'] <= 10].copy()

# %%
# make a horizontal grouped barplot from all_feature_df, group by feature
# x axis: abs_coeff
# y axis: feature
# color: test_or_control

plt.figure(figsize=(10, 10))
sns.barplot(data=all_features_df_sub, x='abs_coeff', y='feature', hue='test_or_control')
plt.show()

# %% [markdown]
# ### remake

# %%
to_predict_ff = False
ref_point_mode = 'time after cur ff visible'
ref_point_value = 0.1
column_for_split = 'nxt_ff_cluster_last_seen_time_bbas'
whether_filter_info = True
finalized_params = {
                    'max_curv_range': 200,
                    'whether_even_out_distribution': True,
                    'whether_limit_cur_ff_cluster_50_size': False,
                    'if_test_nxt_ff_group_appear_after_stop': 'flexible',
                    'if_ctrl_nxt_ff_group_appear_after_stop': 'flexible'
                    }


mtc = monkey_plan_factors_x_sess_class.PlanAcrossSessions()
mtc.quickly_get_plan_x_and_y_control_and_test_data(ref_point_mode, ref_point_value, to_predict_ff=to_predict_ff, keep_monkey_info=True)
mtc.plan_xy_test, mtc.plan_xy_ctrl = plan_factors_utils.quickly_process_plan_xy_test_and_ctrl(mtc.plan_xy_test, mtc.plan_xy_ctrl, column_for_split, whether_filter_info, finalized_params)

# %%
ml_inst = ml_methods_class.MlMethods()
ml_inst.data_source = mtc

all_info = pd.DataFrame()
for y_var_column in all_cur_and_nxt_lr_df['y_var_column'].unique():
    for test_or_control in ['test', 'control']:
        for ref_columns_only in [True, False]:
            mtc.test_or_control = test_or_control
            ml_inst.data_source.streamline_preparing_for_ml(y_var_column, 
                                                ref_columns_only=ref_columns_only,
                                                cluster_to_keep='all',
                                                cluster_for_interaction='none',
                                                add_ref_interaction=True,
                                                winsorize_angle_features=True,
                                                using_lasso=True, 
                                                use_combd_features_for_cluster_only=False,
                                                )
            if (ml_inst.data_source.x_var_df.shape[0] == 0) or (ml_inst.data_source.x_var_df.shape[1] == 0):
                print('no data for y_var_column:', y_var_column)
                continue
            ml_inst.use_train_test_split(ml_inst.data_source.x_var_df, ml_inst.data_source.y_var_df, y_var_column=y_var_column, remove_outliers=True)
            ml_inst.use_linear_regression(show_plot=False)
           

            temp_info = regression_utils.get_significant_features_in_one_row(ml_inst.summary_df, max_features_to_save=None, add_coeff=True)

            # also try cross validation
            x_var, y_var_column = prep_ml_data_utils.further_prepare_x_var_and_y_var(ml_inst.data_source.x_var_df, ml_inst.data_source.y_var_df, y_var_column=y_var_column, remove_outliers=True)
            result = regression_utils.use_linear_regression_cv(x_var, y_var_column)
            temp_info['avg_r_squared'] = result['test_r2_mean']
            temp_info['std_r_squared'] = result['test_r2_std']
            temp_info['y_var_column'] = y_var_column
            temp_info['test_or_control'] = test_or_control
            temp_info['ref_columns_only'] = ref_columns_only
            print('num_features:', x_var.shape[1])

            all_info = pd.concat([all_info, temp_info], axis=0)

    break

# %% [markdown]
# ### plot

# %%
all_info

# %%
ref_columns_only = False
all_info_sub = all_info[all_info['ref_columns_only']==ref_columns_only].copy()
all_features_df = process_variations_utils.make_all_features_df_by_separating_based_on_a_column(all_info_sub)

# %%
# make a horizontal grouped barplot from all_feature_df, group by feature
# x axis: abs_coeff
# y axis: feature
# color: test_or_control

plt.figure(figsize=(10, 10))
sns.barplot(data=all_features_df, x='abs_coeff', y='feature', hue='test_or_control')
plt.show()

# %%
all_info.shape

# %% [markdown]
# # Compare lr and ml
#
# Currently there are problems for the below because lr and ml don't share the same sets of variables

# %%
# for the same y_var_column and the same ref_columns_only and the same ref_point_value, use the best result from lr (see which cluster_for_interaction have the best result)
# and then make plots to compare...?

# %%
osfxs =only_cur_ff_x_sess_class.OnlyStopFFAcrossSessions(monkey_name='monkey_Bruno')
all_only_cur_ml_df = osfxs.make_or_retrieve_all_only_cur_ml_df()
all_only_cur_ml_df = all_only_cur_ml_df[(all_only_cur_ml_df['model'] == 'rf')].copy()

# %%
all_only_cur_lr_df = all_only_cur_lr_df[(all_only_cur_lr_df['using_lasso'] == True) &
                                          (all_only_cur_lr_df['winsorize_angle_features'] == True)].copy()

# %%
sns.histplot(all_only_cur_ml_df['avg_r_squared'] - all_only_cur_ml_df['r_squared_test'])
plt.show()

# %%
all_combined_rows = pd.DataFrame()
columns_to_save = ['y_var_column', 'ref_point_value', 'ref_columns_only', 'avg_r_squared', 'num_features', 'sample_size']
for y_var_column in all_only_cur_ml_df['y_var_column'].unique():
    for ref_point_value in all_only_cur_ml_df['ref_point_value'].unique():
        for ref_columns_only in all_only_cur_ml_df['ref_columns_only'].unique():
            sub_lr = all_only_cur_lr_df[
                                        (all_only_cur_lr_df['y_var_column']==y_var_column) &
                                        (all_only_cur_lr_df['ref_point_value']==ref_point_value) &
                                        (all_only_cur_lr_df['ref_columns_only']==ref_columns_only)
                                        ].copy()
            sub_lr = sub_lr[sub_lr['avg_r_squared'] == sub_lr['avg_r_squared'].max()].iloc[[0]].copy()
            sub_lr = sub_lr[columns_to_save].reset_index(drop=True)
            sub_lr['model'] = 'linear regression'

            sub_ml = all_only_cur_ml_df[
                                        (all_only_cur_ml_df['y_var_column']==y_var_column) &
                                        (all_only_cur_ml_df['ref_point_value']==ref_point_value) &
                                        (all_only_cur_ml_df['ref_columns_only']==ref_columns_only)
                                        ].copy()
            sub_ml = sub_ml[columns_to_save].reset_index(drop=True)       
            sub_ml['model'] = 'random forest'

            combined_row = pd.concat([sub_lr, sub_ml], axis=0)
            if combined_row.shape[0] != 2:
                raise ValueError('combined_row should have 2 rows')
            all_combined_rows = pd.concat([all_combined_rows, combined_row], axis=0)

# %%
columns_with_variations = process_variations_utils.examine_columns(processed_df)

# %%
x_var_column_list = ['ref_point_value', 'model']

fixed_variable_values_to_use = {#'cluster_for_interaction': 'none',
                                #'use_combd_features_for_cluster_only': False,
}

changeable_variables = ['y_var_column', 'ref_point_value']


columns_to_find_unique_combinations_for_color = ['model']

plot_variations_utils.streamline_making_plotly_plot_to_compare_two_sets_of_data(all_combined_rows, 
                                                              fixed_variable_values_to_use,
                                                              changeable_variables,
                                                              x_var_column_list,
                                                              columns_to_find_unique_combinations_for_color=columns_to_find_unique_combinations_for_color)

# %% [markdown]
# # Other plots

# %% [markdown]
# ## show "make dist even" meaning

# %%
test_df = mtc.plan_xy_test.copy()
ctrl_df = mtc.plan_xy_ctrl.copy()

# %%
from planning_analysis.plan_factors import test_vs_control_utils
test_df, ctrl_df = test_vs_control_utils.make_the_distributions_of_distance_more_similar_in_df(test_df, ctrl_df, verbose=True)
test_df, ctrl_df = test_vs_control_utils.make_the_distributions_of_angle_more_similar_in_df(test_df, ctrl_df, verbose=True)

# %%
# Initialize a 3x1 subplot
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

for i, var in enumerate(['cur_ff_distance_at_ref', 'cur_ff_angle_at_ref', 'nxt_ff_angle_at_ref']):
    if 'angle' in var:
        binwidth_1 = 0.05
        binwidth_2 = 0.05
        # binwidth_1 = 0.05
        # binwidth_2 = 0.051
    else:
        binwidth_1 = 5
        binwidth_2 = 5
    
    # Use the ith subplot for plotting
    ax = axes[i]
    sns.histplot(test_df[var], color='blue', stat='probability', binwidth=binwidth_1, label='Test', ax=ax)
    sns.histplot(ctrl_df[var], color='orange', stat='probability', binwidth=binwidth_2, label='Control', ax=ax)
    ax.set_title(var)
    ax.legend()

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %%
for var in ['cur_ff_angle_at_ref', 'nxt_ff_angle_at_ref', 'cur_ff_distance_at_ref']:
    if 'angle' in var:
        binwidth_1 = 0.05
        binwidth_2 = 0.051
    else:
        binwidth_1 = 5
        binwidth_2 = 5.25
    sns.histplot(test_df[var], color='blue', stat='probability', binwidth=binwidth_1, label='Test')
    sns.histplot(ctrl_df[var], color='orange', stat='probability', binwidth=binwidth_2, label='Control')
    plt.title(var)
    plt.legend()
    plt.show()

# %%
'cur_ff_distance_at_ref', 'cur_ff_angle_at_ref', 'nxt_ff_angle_at_ref'

# %% [markdown]
# ## show y_var_column dist

# %%
y_columns_of_interest=['diff_in_d_heading_to_cur_ff',
                        'diff_in_abs_angle_to_nxt_ff',
                        'diff_in_abs_d_curv',
                        'dir_from_cur_ff_to_stop',
                        'd_heading_of_traj',
                        'curv_of_traj_before_stop',
                        ]

# %%
def agg_regrouped_info_func(test_df, ctrl_df):

    test_df = test_df[y_columns_of_interest].copy()
    test_df['test_or_control'] = 'test'
    ctrl_df = ctrl_df[y_columns_of_interest].copy()
    ctrl_df['test_or_control'] = 'control'
    temp_regrouped_info = pd.concat([test_df, ctrl_df], axis=0)
    temp_regrouped_info.reset_index(drop=True, inplace=True)

    return temp_regrouped_info

# %%
to_predict_ff = False
ref_point_mode = 'time after cur ff visible'
ref_point_value = 0.1

mtc = monkey_plan_factors_x_sess_class.PlanAcrossSessions()
mtc.get_plan_x_and_plan_y_across_sessions(ref_point_mode=ref_point_mode, ref_point_value=ref_point_value)
mtc.plan_xy_test, mtc.plan_xy_ctrl = plan_factors_utils.make_plan_xy_test_and_plan_xy_ctrl(mtc.combd_plan_x_tc, mtc.combd_plan_y_tc)

# %%
regrouped_info = make_variations_utils.make_regrouped_info(mtc.plan_xy_test, 
                                                mtc.plan_xy_ctrl, 
                                                agg_regrouped_info_func,
                                                key_for_split_choices=['cluster_seen'],
                                                whether_filter_info_choices=[True],
                                                whether_even_out_distribution_choices=[False],
                                                whether_test_nxt_ff_flash_after_stop_choices=['flexible'],
                                                whether_limit_cur_ff_cluster_50_size_choices=[False],
                                                ctrl_flash_compared_to_test_choices=['flexible'],
                                                max_curv_range_choices=[200],
                                                verbose=True
                                                )

# %%
test_info = regrouped_info[regrouped_info['test_or_control']=='test'].copy()
ctrl_info = regrouped_info[regrouped_info['test_or_control']=='control'].copy()

for y_var_column in y_columns_of_interest:
    sns.histplot(test_info[y_var_column], color='blue', stat='probability')
    sns.histplot(ctrl_info[y_var_column], color='orange', stat='probability')
    plt.title(y_var_column)
    plt.show()
    
    sns.boxplot(data=regrouped_info, x='test_or_control', y=y_var_column)
    plt.title(y_var_column)
    plt.show()

# %% [markdown]
# # Optimal arc comparisons

# %% [markdown]
# ## null arc

# %%
normalize = False
eliminate_outliers = False
use_curv_to_ff_center = False
curv_of_traj_mode = 'distance'
window_for_curv_of_traj=[-25, 25]
raw_data_folder_path = "all_monkey_data/raw_monkey_data/monkey_Bruno/data_0328"

#data_item_info = find_cvn_utils.extract_key_info_from_data_item_for_stops_near_ff_class(data_item)

snf = cvn_from_ref_class.CurVsNxtFfFromRefClasee(raw_data_folder_path=raw_data_folder_path)
snf.get_more_monkey_data()
snf.traj_curv_descr = 'Traj Curv: From Current Point to Right Before Stop'

# %%
# snf.update_opt_arc_type('opt_arc_stop_closest')
# # options are: norm_opt_arc, opt_arc_stop_first_vis_bdry, opt_arc_stop_closest

# %%
snf.streamline_organizing_info(ref_point_mode='distance', ref_point_value=-150, 
                              #ref_point_mode='time after cur ff visible', ref_point_value=0.1, 
                               curv_of_traj_mode=curv_of_traj_mode, window_for_curv_of_traj=window_for_curv_of_traj, truncate_curv_of_traj_by_time_of_capture=True,
                               use_curv_to_ff_center=use_curv_to_ff_center,  eliminate_outliers=eliminate_outliers,
                               stops_near_ff_df_exists_ok=True,
                               )

snf.ax_for_corr = snf.find_relationships_from_info(normalize=normalize, show_plot=True)
snf.prepare_to_plot_stops_near_ff()

# %%
examine_null_arcs.plot_null_arc_ends_in_ff(snf.cur_null_arc_info_for_counted_points, snf.ff_real_position_sorted)

# %%
examine_null_arcs.plot_null_arc_ends_in_ff(snf.cur_null_arc_info_for_counted_points, snf.ff_real_position_sorted,
                                               include_arc_portion_before_entering_ff=True)

# %% [markdown]
# ## monkey Traj into ff

# %% [markdown]
# ### plot

# %%
curv_of_traj_mode = 'distance'
window_for_curv_of_traj=[-25, 25]
raw_data_folder_path = "all_monkey_data/raw_monkey_data/monkey_Schro/data_0326"
pf = plan_factors_class.PlanFactors(raw_data_folder_path=raw_data_folder_path)
pf.get_more_monkey_data()

# %%
valid_subset = monkey_landing_in_ff.get_valid_subset_to_construct_scatter_around_target_df(pf.closest_stop_to_capture_df, pf.monkey_information, pf.ff_real_position_sorted)

# %%
monkey_landing_in_ff.plot_monkey_landings_in_ff(valid_subset.iloc[120:150], pf.monkey_information, pf.ff_real_position_sorted)

# %% [markdown]
# ### scatteredness

# %%
sns.histplot(valid_subset['distance_from_ff_to_stop'])
plt.title('distance_from_ff_to_stop')
plt.show()

# %%
# plot the points in the four quadrants
quadrants = {1: [-90, 0], 2: [0, 90], 3: [90, 180], 4: [-180, -90]}
for quad in range(1, 5):
    valid_subset2 = valid_subset[(valid_subset['angle_in_degrees_from_ff_to_stop'] >= quadrants[quad][0]) & (valid_subset['angle_in_degrees_from_ff_to_stop'] < quadrants[quad][1])].copy()
    print(f'quad: {quad}, num_points: {len(valid_subset2)}')
    monkey_landing_in_ff.plot_monkey_landings_in_ff(valid_subset2, pf.monkey_information, pf.ff_real_position_sorted)

# %% [markdown]
# ### how far is the monkey from the edge of ff

# %%
df['abs_angle_in_degrees'] = df['angle_in_degrees_from_ff_to_stop'].abs()
df.describe()
# calculate the number of points in each quadrant

# %%
sns.histplot(df['angle_in_degrees_from_ff_to_stop'])
plt.show()
plt.close()

# %%
# TBH I don't think the following plots actually make sense

# plot distance against angle_in_degrees
sns.scatterplot(data=df, x='distance_from_ff_to_stop', y='angle_in_degrees_from_ff_to_stop')
# plot a regression line
sns.regplot(data=df, x='distance_from_ff_to_stop', y='angle_in_degrees_from_ff_to_stop', scatter=False)
plt.show()
plt.close()

# plot distance against abs_angle_in_degrees
sns.scatterplot(data=df, x='distance_from_ff_to_stop', y='abs_angle_in_degrees')
# plot a regression line
sns.regplot(data=df, x='distance_from_ff_to_stop', y='abs_angle_in_degrees', scatter=False)
plt.show()

# %% [markdown]
# ### see a trial

# %%
counter = 0
for index, row in closest_stop_to_capture_df.iterrows():
    trial = row['cur_ff_index'].astype(int)
    returned_info = plot_trials.PlotTrials([pf.ff_caught_T_new[trial-1], pf.ff_caught_T_new[trial]+1], 
                pf.monkey_information,
                pf.ff_dataframe, 
                pf.ff_life_sorted, 
                pf.ff_real_position_sorted, 
                pf.ff_believed_position_sorted, 
                None, 
                pf.ff_caught_T_new,
                currentTrial=trial,
                num_trials=1,
                show_believed_target_positions=True,
                show_reward_boundary=True,
                trail_color_var='speed',
                indices_of_ff_to_mark_2nd_kind=[trial],
                point_indices_to_be_marked=row['stop_point_index'].astype(int),
                #adjust_xy_limits=False,
                )
    plt.show()

    if counter == 5:
        break
    counter += 1

# %%
reward_boundary_radius = 25
monkey_sub = monkey_landing_in_ff.iterate_to_get_subset_of_monkey_info(pf.monkey_information, pf.ff_real_position_sorted, int(row.cur_ff_index), row.time, initial_duration_before_stop=2, reward_boundary_radius=reward_boundary_radius)

returned_info = plot_trials.PlotTrials([434, 435], 
               pf.monkey_information,
               pf.ff_dataframe, 
               pf.ff_life_sorted, 
               pf.ff_real_position_sorted, 
               pf.ff_believed_position_sorted, 
               None, 
               pf.ff_caught_T_new,
               None,
               show_believed_target_positions=True,
               show_reward_boundary=True,
               trail_color_var='speed',
               #adjust_xy_limits=False,
               )
plt.show()
